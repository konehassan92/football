# %% [markdown]
# # Librairies

# %%
import soccerdata as sd
import pandas as pd
from datetime import datetime, date, timedelta
import os

# %%
print(sd.FBref())

fbref = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=[2425])
print(fbref.__doc__)
# Out:
# [08/08/25 18:03:35] INFO     Saving cached data to C:\Users\hassa\soccerdata\data\FBref              ]8;id=104311;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=464531;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py#263\263]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=808349;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=429328;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py#475\475]8;;\
# <soccerdata.fbref.FBref object at 0x000001DECF245010>
#                     INFO     Saving cached data to C:\Users\hassa\soccerdata\data\FBref              ]8;id=403306;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=345901;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py#263\263]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
#                       'http': 'http://10.10.1.10:3128',
#                       'https': 'http://10.10.1.10:1080',
#                   }
#
#             - list(dict): A list of proxies to choose from. A different proxy will
#               be selected from this list after failed requests, allowing rotating
#               proxies.
#             - callable: A function that returns a valid proxy. This function will
#               be called after failed requests, allowing rotating proxies.
#     no_cache : bool
#         If True, will not use cached data.
#     no_store : bool
#         If True, will not store downloaded data.
#     data_dir : Path
#         Path to directory where data will be cached.

# %% [markdown]
# # BDD

# %%
stat_joueurs = ['standard', 'keeper', 'keeper_adv', 'shooting', 'passing', 'passing_types', 
                'goal_shot_creation', 'defense', 'possession', 'playing_time', 'misc']
# Dictionnaire pour stocker les DataFrames
joueurs = {}

# Liste pour stocker les noms des tables créées
tables_crees = []

date_heure = datetime.now().strftime("%Y-%m-%d")

# Boucle pour traiter chaque thème/stat_joueurs
for theme in stat_joueurs:
    print(theme)
    
    # Lire les statistiques des joueurs
    joueurs[theme] = fbref.read_player_season_stats(stat_type=theme)
    
    # Modifier les colonnes du DataFrame
    joueurs[theme].columns = ['-'.join(filter(None, col)).strip() for col in joueurs[theme].columns.values]
    joueurs[theme].reset_index(inplace=True)
    joueurs[theme]["clé primaire"] = joueurs[theme]["player"].astype(str) + " - " + joueurs[theme]["team"].astype(str)
    joueurs[theme]["Date de téléchargement"] = date_heure
    joueurs[theme]["theme"] = str(theme)

    # Afficher les informations du DataFrame
    print(joueurs[theme].columns)
    print(joueurs[theme].info())
    print(joueurs[theme].shape)
    
    # Renommer les DataFrames pour utilisation séparée dans le notebook
    globals()[f'joueurs_{theme}'] = joueurs[theme]

    # Ajouter le nom de la table à la liste des tables créées
    tables_crees.append(f'joueurs_{theme}')

# Afficher la liste des tables créées
print("Tables créées:", tables_crees)
# Out:
# standard
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        'Playing Time-MP', 'Playing Time-Starts', 'Playing Time-Min',
#        'Playing Time-90s', 'Performance-Gls', 'Performance-Ast',
#        'Performance-G+A', 'Performance-G-PK', 'Performance-PK',
#        'Performance-PKatt', 'Performance-CrdY', 'Performance-CrdR',
#        'Expected-xG', 'Expected-npxG', 'Expected-xAG', 'Expected-npxG+xAG',
#        'Progression-PrgC', 'Progression-PrgP', 'Progression-PrgR',
#        'Per 90 Minutes-Gls', 'Per 90 Minutes-Ast', 'Per 90 Minutes-G+A',
#        'Per 90 Minutes-G-PK', 'Per 90 Minutes-G+A-PK', 'Per 90 Minutes-xG',
#        'Per 90 Minutes-xAG', 'Per 90 Minutes-xG+xAG', 'Per 90 Minutes-npxG',
#        'Per 90 Minutes-npxG+xAG', 'clé primaire', 'Date de téléchargement',
#        'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   league                   2752 non-null   object
#  1   season                   2752 non-null   object
#  2   team                     2752 non-null   string
#  3   player                   2752 non-null   string
#  4   nation                   2749 non-null   string
#  5   pos                      2752 non-null   string
#  6   age                      2748 non-null   string
#  7   born                     2748 non-null   Int64
#  8   Playing Time-MP          2752 non-null   Int64
#  9   Playing Time-Starts      2752 non-null   Int64
#  10  Playing Time-Min         2752 non-null   Int64
#  11  Playing Time-90s         2752 non-null   Float64
#  12  Performance-Gls          2752 non-null   Int64
#  13  Performance-Ast          2752 non-null   Int64
#  14  Performance-G+A          2752 non-null   Int64
#  15  Performance-G-PK         2752 non-null   Int64
#  16  Performance-PK           2752 non-null   Int64
#  17  Performance-PKatt        2752 non-null   Int64
#  18  Performance-CrdY         2752 non-null   Int64
#  19  Performance-CrdR         2752 non-null   Int64
#  20  Expected-xG              2752 non-null   Float64
#  21  Expected-npxG            2752 non-null   Float64
#  22  Expected-xAG             2752 non-null   Float64
#  23  Expected-npxG+xAG        2752 non-null   Float64
#  24  Progression-PrgC         2752 non-null   Int64
#  25  Progression-PrgP         2752 non-null   Int64
#  26  Progression-PrgR         2752 non-null   Int64
#  27  Per 90 Minutes-Gls       2752 non-null   Float64
#  28  Per 90 Minutes-Ast       2752 non-null   Float64
#  29  Per 90 Minutes-G+A       2752 non-null   Float64
#  30  Per 90 Minutes-G-PK      2752 non-null   Float64
#  31  Per 90 Minutes-G+A-PK    2752 non-null   Float64
#  32  Per 90 Minutes-xG        2752 non-null   Float64
#  33  Per 90 Minutes-xAG       2752 non-null   Float64
#  34  Per 90 Minutes-xG+xAG    2752 non-null   Float64
#  35  Per 90 Minutes-npxG      2752 non-null   Float64
#  36  Per 90 Minutes-npxG+xAG  2752 non-null   Float64
#  37  clé primaire             2752 non-null   object
#  38  Date de téléchargement   2752 non-null   object
#  39  theme                    2752 non-null   object
# dtypes: Float64(15), Int64(15), object(5), string(5)
# memory usage: 940.8+ KB
# None
# (2752, 40)
# keeper
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        'Playing Time-MP', 'Playing Time-Starts', 'Playing Time-Min', '90s',
#        'Performance-GA', 'Performance-GA90', 'Performance-SoTA',
#        'Performance-Saves', 'Performance-Save%', 'Performance-W',
#        'Performance-D', 'Performance-L', 'Performance-CS', 'Performance-CS%',
#        'Penalty Kicks-PKatt', 'Penalty Kicks-PKA', 'Penalty Kicks-PKsv',
#        'Penalty Kicks-PKm', 'Penalty Kicks-Save%', 'clé primaire',
#        'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  193 non-null    object
#  1   season                  193 non-null    object
#  2   team                    193 non-null    string
#  3   player                  193 non-null    string
#  4   nation                  193 non-null    string
#  5   pos                     193 non-null    string
#  6   age                     193 non-null    string
#  7   born                    193 non-null    Int64
#  8   Playing Time-MP         193 non-null    Int64
#  9   Playing Time-Starts     193 non-null    Int64
#  10  Playing Time-Min        193 non-null    Int64
#  11  90s                     193 non-null    Float64
#  12  Performance-GA          193 non-null    Int64
#  13  Performance-GA90        193 non-null    Float64
#  14  Performance-SoTA        193 non-null    Int64
#  15  Performance-Saves       193 non-null    Int64
#  16  Performance-Save%       190 non-null    Float64
#  17  Performance-W           193 non-null    Int64
#  18  Performance-D           193 non-null    Int64
#  19  Performance-L           193 non-null    Int64
#  20  Performance-CS          193 non-null    Int64
#  21  Performance-CS%         188 non-null    Float64
#  22  Penalty Kicks-PKatt     193 non-null    Int64
#  23  Penalty Kicks-PKA       193 non-null    Int64
#  24  Penalty Kicks-PKsv      193 non-null    Int64
#  25  Penalty Kicks-PKm       193 non-null    Int64
#  26  Penalty Kicks-Save%     135 non-null    Float64
#  27  clé primaire            193 non-null    object
#  28  Date de téléchargement  193 non-null    object
#  29  theme                   193 non-null    object
# dtypes: Float64(5), Int64(15), object(5), string(5)
# memory usage: 49.1+ KB
# None
# (193, 30)
# keeper_adv
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Goals-GA', 'Goals-PKA', 'Goals-FK', 'Goals-CK', 'Goals-OG',
#        'Expected-PSxG', 'Expected-PSxG/SoT', 'Expected-PSxG+/-',
#        'Expected-/90', 'Launched-Cmp', 'Launched-Att', 'Launched-Cmp%',
#        'Passes-Att (GK)', 'Passes-Thr', 'Passes-Launch%', 'Passes-AvgLen',
#        'Goal Kicks-Att', 'Goal Kicks-Launch%', 'Goal Kicks-AvgLen',
#        'Crosses-Opp', 'Crosses-Stp', 'Crosses-Stp%', 'Sweeper-#OPA',
#        'Sweeper-#OPA/90', 'Sweeper-AvgDist', 'clé primaire',
#        'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  193 non-null    object
#  1   season                  193 non-null    object
#  2   team                    193 non-null    string
#  3   player                  193 non-null    string
#  4   nation                  193 non-null    string
#  5   pos                     193 non-null    string
#  6   age                     193 non-null    string
#  7   born                    193 non-null    Int64
#  8   90s                     193 non-null    Float64
#  9   Goals-GA                193 non-null    Int64
#  10  Goals-PKA               193 non-null    Int64
#  11  Goals-FK                193 non-null    Int64
#  12  Goals-CK                193 non-null    Int64
#  13  Goals-OG                193 non-null    Int64
#  14  Expected-PSxG           193 non-null    Float64
#  15  Expected-PSxG/SoT       190 non-null    Float64
#  16  Expected-PSxG+/-        193 non-null    Float64
#  17  Expected-/90            193 non-null    Float64
#  18  Launched-Cmp            193 non-null    Int64
#  19  Launched-Att            193 non-null    Int64
#  20  Launched-Cmp%           193 non-null    Float64
#  21  Passes-Att (GK)         193 non-null    Int64
#  22  Passes-Thr              193 non-null    Int64
#  23  Passes-Launch%          193 non-null    Float64
#  24  Passes-AvgLen           193 non-null    Float64
#  25  Goal Kicks-Att          193 non-null    Int64
#  26  Goal Kicks-Launch%      193 non-null    Float64
#  27  Goal Kicks-AvgLen       193 non-null    Float64
#  28  Crosses-Opp             193 non-null    Int64
#  29  Crosses-Stp             193 non-null    Int64
#  30  Crosses-Stp%            193 non-null    Float64
#  31  Sweeper-#OPA            193 non-null    Int64
#  32  Sweeper-#OPA/90         193 non-null    Float64
#  33  Sweeper-AvgDist         192 non-null    Float64
#  34  clé primaire            193 non-null    object
#  35  Date de téléchargement  193 non-null    object
#  36  theme                   193 non-null    object
# dtypes: Float64(13), Int64(14), object(5), string(5)
# memory usage: 61.0+ KB
# None
# (193, 37)
# shooting
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Standard-Gls', 'Standard-Sh', 'Standard-SoT', 'Standard-SoT%',
#        'Standard-Sh/90', 'Standard-SoT/90', 'Standard-G/Sh', 'Standard-G/SoT',
#        'Standard-Dist', 'Standard-FK', 'Standard-PK', 'Standard-PKatt',
#        'Expected-xG', 'Expected-npxG', 'Expected-npxG/Sh', 'Expected-G-xG',
#        'Expected-np:G-xG', 'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   Standard-Gls            2752 non-null   Int64
#  10  Standard-Sh             2752 non-null   Int64
#  11  Standard-SoT            2752 non-null   Int64
#  12  Standard-SoT%           2251 non-null   Float64
#  13  Standard-Sh/90          2752 non-null   Float64
#  14  Standard-SoT/90         2752 non-null   Float64
#  15  Standard-G/Sh           2251 non-null   Float64
#  16  Standard-G/SoT          1832 non-null   Float64
#  17  Standard-Dist           2251 non-null   Float64
#  18  Standard-FK             2752 non-null   Int64
#  19  Standard-PK             2752 non-null   Int64
#  20  Standard-PKatt          2752 non-null   Int64
#  21  Expected-xG             2752 non-null   Float64
#  22  Expected-npxG           2752 non-null   Float64
#  23  Expected-npxG/Sh        2251 non-null   Float64
#  24  Expected-G-xG           2752 non-null   Float64
#  25  Expected-np:G-xG        2752 non-null   Float64
#  26  clé primaire            2752 non-null   object
#  27  Date de téléchargement  2752 non-null   object
#  28  theme                   2752 non-null   object
# dtypes: Float64(12), Int64(7), object(5), string(5)
# memory usage: 674.7+ KB
# None
# (2752, 29)
# passing
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Total-Cmp', 'Total-Att', 'Total-Cmp%', 'Total-TotDist',
#        'Total-PrgDist', 'Short-Cmp', 'Short-Att', 'Short-Cmp%', 'Medium-Cmp',
#        'Medium-Att', 'Medium-Cmp%', 'Long-Cmp', 'Long-Att', 'Long-Cmp%', 'Ast',
#        'xAG', 'Expected-xA', 'Expected-A-xAG', 'KP', '1/3', 'PPA', 'CrsPA',
#        'PrgP', 'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   Total-Cmp               2752 non-null   Int64
#  10  Total-Att               2752 non-null   Int64
#  11  Total-Cmp%              2734 non-null   Float64
#  12  Total-TotDist           2752 non-null   Int64
#  13  Total-PrgDist           2752 non-null   Int64
#  14  Short-Cmp               2752 non-null   Int64
#  15  Short-Att               2752 non-null   Int64
#  16  Short-Cmp%              2712 non-null   Float64
#  17  Medium-Cmp              2752 non-null   Int64
#  18  Medium-Att              2752 non-null   Int64
#  19  Medium-Cmp%             2684 non-null   Float64
#  20  Long-Cmp                2752 non-null   Int64
#  21  Long-Att                2752 non-null   Int64
#  22  Long-Cmp%               2575 non-null   Float64
#  23  Ast                     2752 non-null   Int64
#  24  xAG                     2752 non-null   Float64
#  25  Expected-xA             2752 non-null   Float64
#  26  Expected-A-xAG          2752 non-null   Float64
#  27  KP                      2752 non-null   Int64
#  28  1/3                     2752 non-null   Int64
#  29  PPA                     2752 non-null   Int64
#  30  CrsPA                   2752 non-null   Int64
#  31  PrgP                    2752 non-null   Int64
#  32  clé primaire            2752 non-null   object
#  33  Date de téléchargement  2752 non-null   object
#  34  theme                   2752 non-null   object
# dtypes: Float64(8), Int64(17), object(5), string(5)
# memory usage: 819.8+ KB
# None
# (2752, 35)
# passing_types
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Att', 'Pass Types-Live', 'Pass Types-Dead', 'Pass Types-FK',
#        'Pass Types-TB', 'Pass Types-Sw', 'Pass Types-Crs', 'Pass Types-TI',
#        'Pass Types-CK', 'Corner Kicks-In', 'Corner Kicks-Out',
#        'Corner Kicks-Str', 'Outcomes-Cmp', 'Outcomes-Off', 'Outcomes-Blocks',
#        'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   Att                     2752 non-null   Int64
#  10  Pass Types-Live         2752 non-null   Int64
#  11  Pass Types-Dead         2752 non-null   Int64
#  12  Pass Types-FK           2752 non-null   Int64
#  13  Pass Types-TB           2752 non-null   Int64
#  14  Pass Types-Sw           2752 non-null   Int64
#  15  Pass Types-Crs          2752 non-null   Int64
#  16  Pass Types-TI           2752 non-null   Int64
#  17  Pass Types-CK           2752 non-null   Int64
#  18  Corner Kicks-In         2752 non-null   Int64
#  19  Corner Kicks-Out        2752 non-null   Int64
#  20  Corner Kicks-Str        2752 non-null   Int64
#  21  Outcomes-Cmp            2752 non-null   Int64
#  22  Outcomes-Off            2752 non-null   Int64
#  23  Outcomes-Blocks         2752 non-null   Int64
#  24  clé primaire            2752 non-null   object
#  25  Date de téléchargement  2752 non-null   object
#  26  theme                   2752 non-null   object
# dtypes: Float64(1), Int64(16), object(5), string(5)
# memory usage: 626.3+ KB
# None
# (2752, 27)
# goal_shot_creation
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'SCA-SCA', 'SCA-SCA90', 'SCA Types-PassLive',
#        'SCA Types-PassDead', 'SCA Types-TO', 'SCA Types-Sh', 'SCA Types-Fld',
#        'SCA Types-Def', 'GCA-GCA', 'GCA-GCA90', 'GCA Types-PassLive',
#        'GCA Types-PassDead', 'GCA Types-TO', 'GCA Types-Sh', 'GCA Types-Fld',
#        'GCA Types-Def', 'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   SCA-SCA                 2752 non-null   Int64
#  10  SCA-SCA90               2752 non-null   Float64
#  11  SCA Types-PassLive      2752 non-null   Int64
#  12  SCA Types-PassDead      2752 non-null   Int64
#  13  SCA Types-TO            2752 non-null   Int64
#  14  SCA Types-Sh            2752 non-null   Int64
#  15  SCA Types-Fld           2752 non-null   Int64
#  16  SCA Types-Def           2752 non-null   Int64
#  17  GCA-GCA                 2752 non-null   Int64
#  18  GCA-GCA90               2752 non-null   Float64
#  19  GCA Types-PassLive      2752 non-null   Int64
#  20  GCA Types-PassDead      2752 non-null   Int64
#  21  GCA Types-TO            2752 non-null   Int64
#  22  GCA Types-Sh            2752 non-null   Int64
#  23  GCA Types-Fld           2752 non-null   Int64
#  24  GCA Types-Def           2752 non-null   Int64
#  25  clé primaire            2752 non-null   object
#  26  Date de téléchargement  2752 non-null   object
#  27  theme                   2752 non-null   object
# dtypes: Float64(3), Int64(15), object(5), string(5)
# memory usage: 650.5+ KB
# None
# (2752, 28)
# defense
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Tackles-Tkl', 'Tackles-TklW', 'Tackles-Def 3rd',
#        'Tackles-Mid 3rd', 'Tackles-Att 3rd', 'Challenges-Tkl',
#        'Challenges-Att', 'Challenges-Tkl%', 'Challenges-Lost', 'Blocks-Blocks',
#        'Blocks-Sh', 'Blocks-Pass', 'Int', 'Tkl+Int', 'Clr', 'Err',
#        'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   Tackles-Tkl             2752 non-null   Int64
#  10  Tackles-TklW            2752 non-null   Int64
#  11  Tackles-Def 3rd         2752 non-null   Int64
#  12  Tackles-Mid 3rd         2752 non-null   Int64
#  13  Tackles-Att 3rd         2752 non-null   Int64
#  14  Challenges-Tkl          2752 non-null   Int64
#  15  Challenges-Att          2752 non-null   Int64
#  16  Challenges-Tkl%         2419 non-null   Float64
#  17  Challenges-Lost         2752 non-null   Int64
#  18  Blocks-Blocks           2752 non-null   Int64
#  19  Blocks-Sh               2752 non-null   Int64
#  20  Blocks-Pass             2752 non-null   Int64
#  21  Int                     2752 non-null   Int64
#  22  Tkl+Int                 2752 non-null   Int64
#  23  Clr                     2752 non-null   Int64
#  24  Err                     2752 non-null   Int64
#  25  clé primaire            2752 non-null   object
#  26  Date de téléchargement  2752 non-null   object
#  27  theme                   2752 non-null   object
# dtypes: Float64(2), Int64(16), object(5), string(5)
# memory usage: 650.5+ KB
# None
# (2752, 28)
# possession
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Touches-Touches', 'Touches-Def Pen', 'Touches-Def 3rd',
#        'Touches-Mid 3rd', 'Touches-Att 3rd', 'Touches-Att Pen', 'Touches-Live',
#        'Take-Ons-Att', 'Take-Ons-Succ', 'Take-Ons-Succ%', 'Take-Ons-Tkld',
#        'Take-Ons-Tkld%', 'Carries-Carries', 'Carries-TotDist',
#        'Carries-PrgDist', 'Carries-PrgC', 'Carries-1/3', 'Carries-CPA',
#        'Carries-Mis', 'Carries-Dis', 'Receiving-Rec', 'Receiving-PrgR',
#        'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   Touches-Touches         2752 non-null   Int64
#  10  Touches-Def Pen         2752 non-null   Int64
#  11  Touches-Def 3rd         2752 non-null   Int64
#  12  Touches-Mid 3rd         2752 non-null   Int64
#  13  Touches-Att 3rd         2752 non-null   Int64
#  14  Touches-Att Pen         2752 non-null   Int64
#  15  Touches-Live            2752 non-null   Int64
#  16  Take-Ons-Att            2752 non-null   Int64
#  17  Take-Ons-Succ           2752 non-null   Int64
#  18  Take-Ons-Succ%          2319 non-null   Float64
#  19  Take-Ons-Tkld           2752 non-null   Int64
#  20  Take-Ons-Tkld%          2319 non-null   Float64
#  21  Carries-Carries         2752 non-null   Int64
#  22  Carries-TotDist         2752 non-null   Int64
#  23  Carries-PrgDist         2752 non-null   Int64
#  24  Carries-PrgC            2752 non-null   Int64
#  25  Carries-1/3             2752 non-null   Int64
#  26  Carries-CPA             2752 non-null   Int64
#  27  Carries-Mis             2752 non-null   Int64
#  28  Carries-Dis             2752 non-null   Int64
#  29  Receiving-Rec           2752 non-null   Int64
#  30  Receiving-PrgR          2752 non-null   Int64
#  31  clé primaire            2752 non-null   object
#  32  Date de téléchargement  2752 non-null   object
#  33  theme                   2752 non-null   object
# dtypes: Float64(3), Int64(21), object(5), string(5)
# memory usage: 795.6+ KB
# None
# (2752, 34)
# playing_time
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        'Playing Time-MP', 'Playing Time-Min', 'Playing Time-Mn/MP',
#        'Playing Time-Min%', 'Playing Time-90s', 'Starts-Starts',
#        'Starts-Mn/Start', 'Starts-Compl', 'Subs-Subs', 'Subs-Mn/Sub',
#        'Subs-unSub', 'Team Success-PPM', 'Team Success-onG',
#        'Team Success-onGA', 'Team Success-+/-', 'Team Success-+/-90',
#        'Team Success-On-Off', 'Team Success (xG)-onxG',
#        'Team Success (xG)-onxGA', 'Team Success (xG)-xG+/-',
#        'Team Success (xG)-xG+/-90', 'Team Success (xG)-On-Off', 'clé primaire',
#        'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   league                     3400 non-null   object
#  1   season                     3400 non-null   object
#  2   team                       3400 non-null   string
#  3   player                     3400 non-null   string
#  4   nation                     3390 non-null   string
#  5   pos                        3397 non-null   string
#  6   age                        3391 non-null   string
#  7   born                       3391 non-null   Int64
#  8   Playing Time-MP            3400 non-null   Int64
#  9   Playing Time-Min           2752 non-null   Int64
#  10  Playing Time-Mn/MP         2752 non-null   Int64
#  11  Playing Time-Min%          2754 non-null   Float64
#  12  Playing Time-90s           2754 non-null   Float64
#  13  Starts-Starts              3400 non-null   Int64
#  14  Starts-Mn/Start            2372 non-null   Int64
#  15  Starts-Compl               3400 non-null   Int64
#  16  Subs-Subs                  3400 non-null   Int64
#  17  Subs-Mn/Sub                2276 non-null   Int64
#  18  Subs-unSub                 3400 non-null   Int64
#  19  Team Success-PPM           2754 non-null   Float64
#  20  Team Success-onG           2754 non-null   Int64
#  21  Team Success-onGA          2754 non-null   Int64
#  22  Team Success-+/-           2754 non-null   Int64
#  23  Team Success-+/-90         2752 non-null   Float64
#  24  Team Success-On-Off        2718 non-null   Float64
#  25  Team Success (xG)-onxG     2752 non-null   Float64
#  26  Team Success (xG)-onxGA    2752 non-null   Float64
#  27  Team Success (xG)-xG+/-    2752 non-null   Float64
#  28  Team Success (xG)-xG+/-90  2752 non-null   Float64
#  29  Team Success (xG)-On-Off   2718 non-null   Float64
#  30  clé primaire               3400 non-null   object
#  31  Date de téléchargement     3400 non-null   object
#  32  theme                      3400 non-null   object
# dtypes: Float64(10), Int64(13), object(5), string(5)
# memory usage: 953.1+ KB
# None
# (3400, 33)
# misc
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        '90s', 'Performance-CrdY', 'Performance-CrdR', 'Performance-2CrdY',
#        'Performance-Fls', 'Performance-Fld', 'Performance-Off',
#        'Performance-Crs', 'Performance-Int', 'Performance-TklW',
#        'Performance-PKwon', 'Performance-PKcon', 'Performance-OG',
#        'Performance-Recov', 'Aerial Duels-Won', 'Aerial Duels-Lost',
#        'Aerial Duels-Won%', 'clé primaire', 'Date de téléchargement', 'theme'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2752 entries, 0 to 2751
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   league                  2752 non-null   object
#  1   season                  2752 non-null   object
#  2   team                    2752 non-null   string
#  3   player                  2752 non-null   string
#  4   nation                  2749 non-null   string
#  5   pos                     2752 non-null   string
#  6   age                     2748 non-null   string
#  7   born                    2748 non-null   Int64
#  8   90s                     2752 non-null   Float64
#  9   Performance-CrdY        2752 non-null   Int64
#  10  Performance-CrdR        2752 non-null   Int64
#  11  Performance-2CrdY       2752 non-null   Int64
#  12  Performance-Fls         2752 non-null   Int64
#  13  Performance-Fld         2752 non-null   Int64
#  14  Performance-Off         2752 non-null   Int64
#  15  Performance-Crs         2752 non-null   Int64
#  16  Performance-Int         2752 non-null   Int64
#  17  Performance-TklW        2752 non-null   Int64
#  18  Performance-PKwon       2752 non-null   Int64
#  19  Performance-PKcon       2752 non-null   Int64
#  20  Performance-OG          2752 non-null   Int64
#  21  Performance-Recov       2752 non-null   Int64
#  22  Aerial Duels-Won        2752 non-null   Int64
#  23  Aerial Duels-Lost       2752 non-null   Int64
#  24  Aerial Duels-Won%       2539 non-null   Float64
#  25  clé primaire            2752 non-null   object
#  26  Date de téléchargement  2752 non-null   object
#  27  theme                   2752 non-null   object
# dtypes: Float64(2), Int64(16), object(5), string(5)
# memory usage: 650.5+ KB
# None
# (2752, 28)
# Tables créées: ['joueurs_standard', 'joueurs_keeper', 'joueurs_keeper_adv', 'joueurs_shooting', 'joueurs_passing', 'joueurs_passing_types', 'joueurs_goal_shot_creation', 'joueurs_defense', 'joueurs_possession', 'joueurs_playing_time', 'joueurs_misc']

# %%
stat_equipes = ['standard', 'keeper', 'keeper_adv', 'shooting', 'passing', 'passing_types', 'goal_shot_creation', 'defense', 'possession', 'playing_time', 'misc']

# Dictionnaire pour stocker les DataFrames
equipes = {}
# Liste pour stocker les noms des tables créées
tables_crees = []

# Boucle pour traiter chaque thème/stat_joueur
for theme in stat_equipes:
    print(theme)
    
    # Lire les statistiques des joueurs
    equipes[theme] = fbref.read_team_season_stats(stat_type=theme)
    
    # Modifier les colonnes du DataFrame
    equipes[theme].columns = ['-'.join(filter(None, col)).strip() for col in equipes[theme].columns.values]
    equipes[theme].reset_index(inplace=True)

    # Afficher les informations du DataFrame
    print(equipes[theme].columns)
    print(equipes[theme].info())
    print(equipes[theme].shape)
    
    # Renommer les DataFrames pour utilisation séparée dans le notebook
    globals()[f'equipes_{theme}'] = equipes[theme]
    
    # Ajouter le nom de la table à la liste des tables créées
    tables_crees.append(f'equipes_{theme}')
    

# Afficher la liste des tables créées
print("Tables créées:", tables_crees)
# Out:
# standard
# Index(['league', 'season', 'team', 'players_used', 'Age', 'Poss',
#        'Playing Time-MP', 'Playing Time-Starts', 'Playing Time-Min',
#        'Playing Time-90s', 'Performance-Gls', 'Performance-Ast',
#        'Performance-G+A', 'Performance-G-PK', 'Performance-PK',
#        'Performance-PKatt', 'Performance-CrdY', 'Performance-CrdR',
#        'Expected-xG', 'Expected-npxG', 'Expected-xAG', 'Expected-npxG+xAG',
#        'Progression-PrgC', 'Progression-PrgP', 'Per 90 Minutes-Gls',
#        'Per 90 Minutes-Ast', 'Per 90 Minutes-G+A', 'Per 90 Minutes-G-PK',
#        'Per 90 Minutes-G+A-PK', 'Per 90 Minutes-xG', 'Per 90 Minutes-xAG',
#        'Per 90 Minutes-xG+xAG', 'Per 90 Minutes-npxG',
#        'Per 90 Minutes-npxG+xAG', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   league                   96 non-null     object
#  1   season                   96 non-null     object
#  2   team                     96 non-null     string
#  3   players_used             96 non-null     Int64
#  4   Age                      96 non-null     Float64
#  5   Poss                     96 non-null     Float64
#  6   Playing Time-MP          96 non-null     Int64
#  7   Playing Time-Starts      96 non-null     Int64
#  8   Playing Time-Min         96 non-null     Int64
#  9   Playing Time-90s         96 non-null     Float64
#  10  Performance-Gls          96 non-null     Int64
#  11  Performance-Ast          96 non-null     Int64
#  12  Performance-G+A          96 non-null     Int64
#  13  Performance-G-PK         96 non-null     Int64
#  14  Performance-PK           96 non-null     Int64
#  15  Performance-PKatt        96 non-null     Int64
#  16  Performance-CrdY         96 non-null     Int64
#  17  Performance-CrdR         96 non-null     Int64
#  18  Expected-xG              96 non-null     Float64
#  19  Expected-npxG            96 non-null     Float64
#  20  Expected-xAG             96 non-null     Float64
#  21  Expected-npxG+xAG        96 non-null     Float64
#  22  Progression-PrgC         96 non-null     Int64
#  23  Progression-PrgP         96 non-null     Int64
#  24  Per 90 Minutes-Gls       96 non-null     Float64
#  25  Per 90 Minutes-Ast       96 non-null     Float64
#  26  Per 90 Minutes-G+A       96 non-null     Float64
#  27  Per 90 Minutes-G-PK      96 non-null     Float64
#  28  Per 90 Minutes-G+A-PK    96 non-null     Float64
#  29  Per 90 Minutes-xG        96 non-null     Float64
#  30  Per 90 Minutes-xAG       96 non-null     Float64
#  31  Per 90 Minutes-xG+xAG    96 non-null     Float64
#  32  Per 90 Minutes-npxG      96 non-null     Float64
#  33  Per 90 Minutes-npxG+xAG  96 non-null     Float64
#  34  url                      96 non-null     object
# dtypes: Float64(17), Int64(14), object(3), string(1)
# memory usage: 29.3+ KB
# None
# (96, 35)
# keeper
# Index(['league', 'season', 'team', 'players_used', 'Playing Time-MP',
#        'Playing Time-Starts', 'Playing Time-Min', '90s', 'Performance-GA',
#        'Performance-GA90', 'Performance-SoTA', 'Performance-Saves',
#        'Performance-Save%', 'Performance-W', 'Performance-D', 'Performance-L',
#        'Performance-CS', 'Performance-CS%', 'Penalty Kicks-PKatt',
#        'Penalty Kicks-PKA', 'Penalty Kicks-PKsv', 'Penalty Kicks-PKm',
#        'Penalty Kicks-Save%', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   league               96 non-null     object
#  1   season               96 non-null     object
#  2   team                 96 non-null     string
#  3   players_used         96 non-null     Int64
#  4   Playing Time-MP      96 non-null     Int64
#  5   Playing Time-Starts  96 non-null     Int64
#  6   Playing Time-Min     96 non-null     Int64
#  7   90s                  96 non-null     Float64
#  8   Performance-GA       96 non-null     Int64
#  9   Performance-GA90     96 non-null     Float64
#  10  Performance-SoTA     96 non-null     Int64
#  11  Performance-Saves    96 non-null     Int64
#  12  Performance-Save%    96 non-null     Float64
#  13  Performance-W        96 non-null     Int64
#  14  Performance-D        96 non-null     Int64
#  15  Performance-L        96 non-null     Int64
#  16  Performance-CS       96 non-null     Int64
#  17  Performance-CS%      96 non-null     Float64
#  18  Penalty Kicks-PKatt  96 non-null     Int64
#  19  Penalty Kicks-PKA    96 non-null     Int64
#  20  Penalty Kicks-PKsv   96 non-null     Int64
#  21  Penalty Kicks-PKm    96 non-null     Int64
#  22  Penalty Kicks-Save%  95 non-null     Float64
#  23  url                  96 non-null     object
# dtypes: Float64(5), Int64(15), object(3), string(1)
# memory usage: 20.0+ KB
# None
# (96, 24)
# keeper_adv
# Index(['league', 'season', 'team', 'players_used', '90s', 'Goals-GA',
#        'Goals-PKA', 'Goals-FK', 'Goals-CK', 'Goals-OG', 'Expected-PSxG',
#        'Expected-PSxG/SoT', 'Expected-PSxG+/-', 'Expected-/90', 'Launched-Cmp',
#        'Launched-Att', 'Launched-Cmp%', 'Passes-Att (GK)', 'Passes-Thr',
#        'Passes-Launch%', 'Passes-AvgLen', 'Goal Kicks-Att',
#        'Goal Kicks-Launch%', 'Goal Kicks-AvgLen', 'Crosses-Opp', 'Crosses-Stp',
#        'Crosses-Stp%', 'Sweeper-#OPA', 'Sweeper-#OPA/90', 'Sweeper-AvgDist',
#        'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   league              96 non-null     object
#  1   season              96 non-null     object
#  2   team                96 non-null     string
#  3   players_used        96 non-null     Int64
#  4   90s                 96 non-null     Float64
#  5   Goals-GA            96 non-null     Int64
#  6   Goals-PKA           96 non-null     Int64
#  7   Goals-FK            96 non-null     Int64
#  8   Goals-CK            96 non-null     Int64
#  9   Goals-OG            96 non-null     Int64
#  10  Expected-PSxG       96 non-null     Float64
#  11  Expected-PSxG/SoT   96 non-null     Float64
#  12  Expected-PSxG+/-    96 non-null     Float64
#  13  Expected-/90        96 non-null     Float64
#  14  Launched-Cmp        96 non-null     Int64
#  15  Launched-Att        96 non-null     Int64
#  16  Launched-Cmp%       96 non-null     Float64
#  17  Passes-Att (GK)     96 non-null     Int64
#  18  Passes-Thr          96 non-null     Int64
#  19  Passes-Launch%      96 non-null     Float64
#  20  Passes-AvgLen       96 non-null     Float64
#  21  Goal Kicks-Att      96 non-null     Int64
#  22  Goal Kicks-Launch%  96 non-null     Float64
#  23  Goal Kicks-AvgLen   96 non-null     Float64
#  24  Crosses-Opp         96 non-null     Int64
#  25  Crosses-Stp         96 non-null     Int64
#  26  Crosses-Stp%        96 non-null     Float64
#  27  Sweeper-#OPA        96 non-null     Int64
#  28  Sweeper-#OPA/90     96 non-null     Float64
#  29  Sweeper-AvgDist     96 non-null     Float64
#  30  url                 96 non-null     object
# dtypes: Float64(13), Int64(14), object(3), string(1)
# memory usage: 25.9+ KB
# None
# (96, 31)
# shooting
# Index(['league', 'season', 'team', 'players_used', '90s', 'Standard-Gls',
#        'Standard-Sh', 'Standard-SoT', 'Standard-SoT%', 'Standard-Sh/90',
#        'Standard-SoT/90', 'Standard-G/Sh', 'Standard-G/SoT', 'Standard-Dist',
#        'Standard-FK', 'Standard-PK', 'Standard-PKatt', 'Expected-xG',
#        'Expected-npxG', 'Expected-npxG/Sh', 'Expected-G-xG',
#        'Expected-np:G-xG', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   league            96 non-null     object
#  1   season            96 non-null     object
#  2   team              96 non-null     string
#  3   players_used      96 non-null     Int64
#  4   90s               96 non-null     Float64
#  5   Standard-Gls      96 non-null     Int64
#  6   Standard-Sh       96 non-null     Int64
#  7   Standard-SoT      96 non-null     Int64
#  8   Standard-SoT%     96 non-null     Float64
#  9   Standard-Sh/90    96 non-null     Float64
#  10  Standard-SoT/90   96 non-null     Float64
#  11  Standard-G/Sh     96 non-null     Float64
#  12  Standard-G/SoT    96 non-null     Float64
#  13  Standard-Dist     96 non-null     Float64
#  14  Standard-FK       96 non-null     Int64
#  15  Standard-PK       96 non-null     Int64
#  16  Standard-PKatt    96 non-null     Int64
#  17  Expected-xG       96 non-null     Float64
#  18  Expected-npxG     96 non-null     Float64
#  19  Expected-npxG/Sh  96 non-null     Float64
#  20  Expected-G-xG     96 non-null     Float64
#  21  Expected-np:G-xG  96 non-null     Float64
#  22  url               96 non-null     object
# dtypes: Float64(12), Int64(7), object(3), string(1)
# memory usage: 19.2+ KB
# None
# (96, 23)
# passing
# Index(['league', 'season', 'team', 'players_used', '90s', 'Total-Cmp',
#        'Total-Att', 'Total-Cmp%', 'Total-TotDist', 'Total-PrgDist',
#        'Short-Cmp', 'Short-Att', 'Short-Cmp%', 'Medium-Cmp', 'Medium-Att',
#        'Medium-Cmp%', 'Long-Cmp', 'Long-Att', 'Long-Cmp%', 'Ast', 'xAG',
#        'Expected-xA', 'Expected-A-xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'PrgP',
#        'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   league          96 non-null     object
#  1   season          96 non-null     object
#  2   team            96 non-null     string
#  3   players_used    96 non-null     Int64
#  4   90s             96 non-null     Float64
#  5   Total-Cmp       96 non-null     Int64
#  6   Total-Att       96 non-null     Int64
#  7   Total-Cmp%      96 non-null     Float64
#  8   Total-TotDist   96 non-null     Int64
#  9   Total-PrgDist   96 non-null     Int64
#  10  Short-Cmp       96 non-null     Int64
#  11  Short-Att       96 non-null     Int64
#  12  Short-Cmp%      96 non-null     Float64
#  13  Medium-Cmp      96 non-null     Int64
#  14  Medium-Att      96 non-null     Int64
#  15  Medium-Cmp%     96 non-null     Float64
#  16  Long-Cmp        96 non-null     Int64
#  17  Long-Att        96 non-null     Int64
#  18  Long-Cmp%       96 non-null     Float64
#  19  Ast             96 non-null     Int64
#  20  xAG             96 non-null     Float64
#  21  Expected-xA     96 non-null     Float64
#  22  Expected-A-xAG  96 non-null     Float64
#  23  KP              96 non-null     Int64
#  24  1/3             96 non-null     Int64
#  25  PPA             96 non-null     Int64
#  26  CrsPA           96 non-null     Int64
#  27  PrgP            96 non-null     Int64
#  28  url             96 non-null     object
# dtypes: Float64(8), Int64(17), object(3), string(1)
# memory usage: 24.2+ KB
# None
# (96, 29)
# passing_types
# Index(['league', 'season', 'team', 'players_used', '90s', 'Att',
#        'Pass Types-Live', 'Pass Types-Dead', 'Pass Types-FK', 'Pass Types-TB',
#        'Pass Types-Sw', 'Pass Types-Crs', 'Pass Types-TI', 'Pass Types-CK',
#        'Corner Kicks-In', 'Corner Kicks-Out', 'Corner Kicks-Str',
#        'Outcomes-Cmp', 'Outcomes-Off', 'Outcomes-Blocks', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   league            96 non-null     object
#  1   season            96 non-null     object
#  2   team              96 non-null     string
#  3   players_used      96 non-null     Int64
#  4   90s               96 non-null     Float64
#  5   Att               96 non-null     Int64
#  6   Pass Types-Live   96 non-null     Int64
#  7   Pass Types-Dead   96 non-null     Int64
#  8   Pass Types-FK     96 non-null     Int64
#  9   Pass Types-TB     96 non-null     Int64
#  10  Pass Types-Sw     96 non-null     Int64
#  11  Pass Types-Crs    96 non-null     Int64
#  12  Pass Types-TI     96 non-null     Int64
#  13  Pass Types-CK     96 non-null     Int64
#  14  Corner Kicks-In   96 non-null     Int64
#  15  Corner Kicks-Out  96 non-null     Int64
#  16  Corner Kicks-Str  96 non-null     Int64
#  17  Outcomes-Cmp      96 non-null     Int64
#  18  Outcomes-Off      96 non-null     Int64
#  19  Outcomes-Blocks   96 non-null     Int64
#  20  url               96 non-null     object
# dtypes: Float64(1), Int64(16), object(3), string(1)
# memory usage: 17.5+ KB
# None
# (96, 21)
# goal_shot_creation
# Index(['league', 'season', 'team', 'players_used', '90s', 'SCA-SCA',
#        'SCA-SCA90', 'SCA Types-PassLive', 'SCA Types-PassDead', 'SCA Types-TO',
#        'SCA Types-Sh', 'SCA Types-Fld', 'SCA Types-Def', 'GCA-GCA',
#        'GCA-GCA90', 'GCA Types-PassLive', 'GCA Types-PassDead', 'GCA Types-TO',
#        'GCA Types-Sh', 'GCA Types-Fld', 'GCA Types-Def', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   league              96 non-null     object
#  1   season              96 non-null     object
#  2   team                96 non-null     string
#  3   players_used        96 non-null     Int64
#  4   90s                 96 non-null     Float64
#  5   SCA-SCA             96 non-null     Int64
#  6   SCA-SCA90           96 non-null     Float64
#  7   SCA Types-PassLive  96 non-null     Int64
#  8   SCA Types-PassDead  96 non-null     Int64
#  9   SCA Types-TO        96 non-null     Int64
#  10  SCA Types-Sh        96 non-null     Int64
#  11  SCA Types-Fld       96 non-null     Int64
#  12  SCA Types-Def       96 non-null     Int64
#  13  GCA-GCA             96 non-null     Int64
#  14  GCA-GCA90           96 non-null     Float64
#  15  GCA Types-PassLive  96 non-null     Int64
#  16  GCA Types-PassDead  96 non-null     Int64
#  17  GCA Types-TO        96 non-null     Int64
#  18  GCA Types-Sh        96 non-null     Int64
#  19  GCA Types-Fld       96 non-null     Int64
#  20  GCA Types-Def       96 non-null     Int64
#  21  url                 96 non-null     object
# dtypes: Float64(3), Int64(15), object(3), string(1)
# memory usage: 18.3+ KB
# None
# (96, 22)
# defense
# Index(['league', 'season', 'team', 'players_used', '90s', 'Tackles-Tkl',
#        'Tackles-TklW', 'Tackles-Def 3rd', 'Tackles-Mid 3rd', 'Tackles-Att 3rd',
#        'Challenges-Tkl', 'Challenges-Att', 'Challenges-Tkl%',
#        'Challenges-Lost', 'Blocks-Blocks', 'Blocks-Sh', 'Blocks-Pass', 'Int',
#        'Tkl+Int', 'Clr', 'Err', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   league           96 non-null     object
#  1   season           96 non-null     object
#  2   team             96 non-null     string
#  3   players_used     96 non-null     Int64
#  4   90s              96 non-null     Float64
#  5   Tackles-Tkl      96 non-null     Int64
#  6   Tackles-TklW     96 non-null     Int64
#  7   Tackles-Def 3rd  96 non-null     Int64
#  8   Tackles-Mid 3rd  96 non-null     Int64
#  9   Tackles-Att 3rd  96 non-null     Int64
#  10  Challenges-Tkl   96 non-null     Int64
#  11  Challenges-Att   96 non-null     Int64
#  12  Challenges-Tkl%  96 non-null     Float64
#  13  Challenges-Lost  96 non-null     Int64
#  14  Blocks-Blocks    96 non-null     Int64
#  15  Blocks-Sh        96 non-null     Int64
#  16  Blocks-Pass      96 non-null     Int64
#  17  Int              96 non-null     Int64
#  18  Tkl+Int          96 non-null     Int64
#  19  Clr              96 non-null     Int64
#  20  Err              96 non-null     Int64
#  21  url              96 non-null     object
# dtypes: Float64(2), Int64(16), object(3), string(1)
# memory usage: 18.3+ KB
# None
# (96, 22)
# possession
# Index(['league', 'season', 'team', 'players_used', 'Poss', '90s',
#        'Touches-Touches', 'Touches-Def Pen', 'Touches-Def 3rd',
#        'Touches-Mid 3rd', 'Touches-Att 3rd', 'Touches-Att Pen', 'Touches-Live',
#        'Take-Ons-Att', 'Take-Ons-Succ', 'Take-Ons-Succ%', 'Take-Ons-Tkld',
#        'Take-Ons-Tkld%', 'Carries-Carries', 'Carries-TotDist',
#        'Carries-PrgDist', 'Carries-PrgC', 'Carries-1/3', 'Carries-CPA',
#        'Carries-Mis', 'Carries-Dis', 'Receiving-Rec', 'Receiving-PrgR', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   league           96 non-null     object
#  1   season           96 non-null     object
#  2   team             96 non-null     string
#  3   players_used     96 non-null     Int64
#  4   Poss             96 non-null     Float64
#  5   90s              96 non-null     Float64
#  6   Touches-Touches  96 non-null     Int64
#  7   Touches-Def Pen  96 non-null     Int64
#  8   Touches-Def 3rd  96 non-null     Int64
#  9   Touches-Mid 3rd  96 non-null     Int64
#  10  Touches-Att 3rd  96 non-null     Int64
#  11  Touches-Att Pen  96 non-null     Int64
#  12  Touches-Live     96 non-null     Int64
#  13  Take-Ons-Att     96 non-null     Int64
#  14  Take-Ons-Succ    96 non-null     Int64
#  15  Take-Ons-Succ%   96 non-null     Float64
#  16  Take-Ons-Tkld    96 non-null     Int64
#  17  Take-Ons-Tkld%   96 non-null     Float64
#  18  Carries-Carries  96 non-null     Int64
#  19  Carries-TotDist  96 non-null     Int64
#  20  Carries-PrgDist  96 non-null     Int64
#  21  Carries-PrgC     96 non-null     Int64
#  22  Carries-1/3      96 non-null     Int64
#  23  Carries-CPA      96 non-null     Int64
#  24  Carries-Mis      96 non-null     Int64
#  25  Carries-Dis      96 non-null     Int64
#  26  Receiving-Rec    96 non-null     Int64
#  27  Receiving-PrgR   96 non-null     Int64
#  28  url              96 non-null     object
# dtypes: Float64(4), Int64(21), object(3), string(1)
# memory usage: 24.2+ KB
# None
# (96, 29)
# playing_time
# Index(['league', 'season', 'team', 'players_used', 'Age', 'Playing Time-MP',
#        'Playing Time-Min', 'Playing Time-Mn/MP', 'Playing Time-Min%',
#        'Playing Time-90s', 'Starts-Starts', 'Starts-Mn/Start', 'Starts-Compl',
#        'Subs-Subs', 'Subs-Mn/Sub', 'Subs-unSub', 'Team Success-PPM',
#        'Team Success-onG', 'Team Success-onGA', 'Team Success-+/-',
#        'Team Success-+/-90', 'Team Success (xG)-onxG',
#        'Team Success (xG)-onxGA', 'Team Success (xG)-xG+/-',
#        'Team Success (xG)-xG+/-90', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   league                     96 non-null     object
#  1   season                     96 non-null     object
#  2   team                       96 non-null     string
#  3   players_used               96 non-null     Int64
#  4   Age                        96 non-null     Float64
#  5   Playing Time-MP            96 non-null     Int64
#  6   Playing Time-Min           96 non-null     Int64
#  7   Playing Time-Mn/MP         96 non-null     Int64
#  8   Playing Time-Min%          96 non-null     Int64
#  9   Playing Time-90s           96 non-null     Float64
#  10  Starts-Starts              96 non-null     Int64
#  11  Starts-Mn/Start            96 non-null     Int64
#  12  Starts-Compl               96 non-null     Int64
#  13  Subs-Subs                  96 non-null     Int64
#  14  Subs-Mn/Sub                96 non-null     Int64
#  15  Subs-unSub                 96 non-null     Int64
#  16  Team Success-PPM           96 non-null     Float64
#  17  Team Success-onG           96 non-null     Int64
#  18  Team Success-onGA          96 non-null     Int64
#  19  Team Success-+/-           96 non-null     Int64
#  20  Team Success-+/-90         96 non-null     Float64
#  21  Team Success (xG)-onxG     96 non-null     Float64
#  22  Team Success (xG)-onxGA    96 non-null     Float64
#  23  Team Success (xG)-xG+/-    96 non-null     Float64
#  24  Team Success (xG)-xG+/-90  96 non-null     Float64
#  25  url                        96 non-null     object
# dtypes: Float64(8), Int64(14), object(3), string(1)
# memory usage: 21.7+ KB
# None
# (96, 26)
# misc
# Index(['league', 'season', 'team', 'players_used', '90s', 'Performance-CrdY',
#        'Performance-CrdR', 'Performance-2CrdY', 'Performance-Fls',
#        'Performance-Fld', 'Performance-Off', 'Performance-Crs',
#        'Performance-Int', 'Performance-TklW', 'Performance-PKwon',
#        'Performance-PKcon', 'Performance-OG', 'Performance-Recov',
#        'Aerial Duels-Won', 'Aerial Duels-Lost', 'Aerial Duels-Won%', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   league             96 non-null     object
#  1   season             96 non-null     object
#  2   team               96 non-null     string
#  3   players_used       96 non-null     Int64
#  4   90s                96 non-null     Float64
#  5   Performance-CrdY   96 non-null     Int64
#  6   Performance-CrdR   96 non-null     Int64
#  7   Performance-2CrdY  96 non-null     Int64
#  8   Performance-Fls    96 non-null     Int64
#  9   Performance-Fld    96 non-null     Int64
#  10  Performance-Off    96 non-null     Int64
#  11  Performance-Crs    96 non-null     Int64
#  12  Performance-Int    96 non-null     Int64
#  13  Performance-TklW   96 non-null     Int64
#  14  Performance-PKwon  96 non-null     Int64
#  15  Performance-PKcon  96 non-null     Int64
#  16  Performance-OG     96 non-null     Int64
#  17  Performance-Recov  96 non-null     Int64
#  18  Aerial Duels-Won   96 non-null     Int64
#  19  Aerial Duels-Lost  96 non-null     Int64
#  20  Aerial Duels-Won%  96 non-null     Float64
#  21  url                96 non-null     object
# dtypes: Float64(2), Int64(16), object(3), string(1)
# memory usage: 18.3+ KB
# None
# (96, 22)
# Tables créées: ['equipes_standard', 'equipes_keeper', 'equipes_keeper_adv', 'equipes_shooting', 'equipes_passing', 'equipes_passing_types', 'equipes_goal_shot_creation', 'equipes_defense', 'equipes_possession', 'equipes_playing_time', 'equipes_misc']

# %% [markdown]
# # Nettoyage

# %% [markdown]
# ##### Nom des nouvelles colonnes

# %%
col_standard = [
    "ligue",                      # inchangé
    "saison",                      # inchangé
    "equipe",                        # inchangé
    "joueur",                      # inchangé
    "nationalite",                 # 'nation'
    "poste",                       # 'pos'
    "age",                         # 'age'
    "annee_naissance",            # 'born'

    # Temps de jeu
    "matchs_joues",               # 'Playing Time-MP'
    "titularisations",            # 'Playing Time-Starts'
    "minutes_jouees",            # 'Playing Time-Min'
    "matchs_90_minutes",         # 'Playing Time-90s'

    # Performance
    "buts",                       # 'Performance-Gls'
    "passes_decisives",          # 'Performance-Ast'
    "buts_plus_passes",          # 'Performance-G+A'
    "buts_hors_penalty",         # 'Performance-G-PK'
    "penaltys_marques",          # 'Performance-PK'
    "penaltys_tentes",           # 'Performance-PKatt'
    "cartons_jaunes",            # 'Performance-CrdY'
    "cartons_rouges",            # 'Performance-CrdR'

    # Expected (statistiques attendues)
    "buts_attendus",                         # 'Expected-xG'
    "buts_attendus_hors_penalty",           # 'Expected-npxG'
    "passes_attendues",                     # 'Expected-xAG'
    "buts_hors_penalty_plus_passes_attendues", # 'Expected-npxG+xAG'

    # Progression
    "conduites_progressives",     # 'Progression-PrgC'
    "passes_progressives",        # 'Progression-PrgP'
    "passes_progressives_recues", # 'Progression-PrgR'

    # Par 90 minutes
    "buts_par_90",                              # 'Per 90 Minutes-Gls'
    "passes_decisives_par_90",                 # 'Per 90 Minutes-Ast'
    "buts_plus_passes_par_90",                 # 'Per 90 Minutes-G+A'
    "buts_hors_penalty_par_90",                # 'Per 90 Minutes-G-PK'
    "buts_plus_passes_hors_penalty_par_90",    # 'Per 90 Minutes-G+A-PK'
    "buts_attendus_par_90",                    # 'Per 90 Minutes-xG'
    "passes_attendues_par_90",                 # 'Per 90 Minutes-xAG'
    "buts_plus_passes_attendues_par_90",       # 'Per 90 Minutes-xG+xAG'
    "buts_attendus_hors_penalty_par_90",       # 'Per 90 Minutes-npxG'
    "buts_hors_penalty_plus_passes_attendues_90", # 'Per 90 Minutes-npxG+xAG'

    # Autres
    "cle_primaire",               # 'clé primaire'
    "date_telechargement",        # 'Date de téléchargement'
    "theme"                       # 'theme'
]


col_gardien = [
    "ligue",                          # inchangé
    "saison",                          # inchangé
    "equipe",                            # inchangé
    "joueur",                          # inchangé
    "nationalite",                     # nation
    "poste",                           # pos
    "age",                             # age
    "annee_naissance",                # born

    # Temps de jeu
    "matchs_joues",                   # Playing Time-MP
    "titularisations",                # Playing Time-Starts
    "minutes_jouees",                # Playing Time-Min
    "matchs_90_minutes",             # 90s

    # Performance défensive gardien
    "buts_encaisses",                # Performance-GA
    "buts_encaisses_par_90",        # Performance-GA90
    "tirs_cadres_subis",            # Performance-SoTA
    "arrets",                        # Performance-Saves
    "pourcentage_arrets",           # Performance-Save%
    "victoires",                     # Performance-W
    "nuls",                          # Performance-D
    "defaites",                      # Performance-L
    "clean_sheets",                 # Performance-CS
    "pourcentage_clean_sheets",    # Performance-CS%

    # Penaltys
    "penaltys_tentes",              # Penalty Kicks-PKatt
    "penaltys_concedes",           # Penalty Kicks-PKA
    "penaltys_arretes",            # Penalty Kicks-PKsv
    "penaltys_rates",              # Penalty Kicks-PKm
    "pourcentage_arrets_penalty", # Penalty Kicks-Save%

    # Métadonnées
    "cle_primaire",                 # clé primaire
    "date_telechargement",          # Date de téléchargement
    "theme"                         # theme
]


col_actions_creation = [
    "ligue",                      # Ligue
    "saison",                     # Saison
    "equipe",                     # Équipe
    "joueur",                     # Joueur
    "nationalite",                # Nationalité
    "poste",                      # Poste
    "age",                        # Âge
    "annee_naissance",            # Année de naissance
    "temps_90s",                  # Temps de jeu en équivalent 90 minutes

    # Actions menant à un tir
    "action_tir_total",           # Total d’actions menant à un tir
    "action_tir_par_90",          # Actions menant à un tir par 90 minutes
    "action_tir_passes_vives",    # Passes en jeu menant à un tir
    "action_tir_passes_mortes",   # Passes arrêtées menant à un tir
    "action_tir_dribbles",        # Dribbles menant à un tir
    "action_tir_tirs",            # Tirs menant à un autre tir
    "action_tir_fautes_subies",   # Fautes subies menant à un tir
    "action_tir_actions_def",     # Actions défensives menant à un tir

    # Actions menant à un but
    "action_but_total",           # Total d’actions menant à un but
    "action_but_par_90",          # Actions menant à un but par 90 minutes
    "action_but_passes_vives",    # Passes en jeu menant à un but
    "action_but_passes_mortes",   # Passes arrêtées menant à un but
    "action_but_dribbles",        # Dribbles menant à un but
    "action_but_tirs",            # Tirs menant à un but
    "action_but_fautes_subies",   # Fautes subies menant à un but
    "action_but_actions_def",     # Actions défensives menant à un but

    # Autres colonnes techniques
    "cle_primaire",               # Clé primaire
    "date_telechargement",        # Date de téléchargement
    "theme"                       # Thème
]

# %% [markdown]
# ## Joueurs

# %%
joueurs_standard.columns = col_standard
joueurs_standard.columns
# Out:
# Index(['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age',
#        'annee_naissance', 'matchs_joues', 'titularisations', 'minutes_jouees',
#        'matchs_90_minutes', 'buts', 'passes_decisives', 'buts_plus_passes',
#        'buts_hors_penalty', 'penaltys_marques', 'penaltys_tentes',
#        'cartons_jaunes', 'cartons_rouges', 'buts_attendus',
#        'buts_attendus_hors_penalty', 'passes_attendues',
#        'buts_hors_penalty_plus_passes_attendues', 'conduites_progressives',
#        'passes_progressives', 'passes_progressives_recues', 'buts_par_90',
#        'passes_decisives_par_90', 'buts_plus_passes_par_90',
#        'buts_hors_penalty_par_90', 'buts_plus_passes_hors_penalty_par_90',
#        'buts_attendus_par_90', 'passes_attendues_par_90',
#        'buts_plus_passes_attendues_par_90',
#        'buts_attendus_hors_penalty_par_90',
#        'buts_hors_penalty_plus_passes_attendues_90', 'cle_primaire',
#        'date_telechargement', 'theme'],
#       dtype='object')

# %%
joueurs_keeper.columns = col_gardien
joueurs_keeper.columns
# Out:
# Index(['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age',
#        'annee_naissance', 'matchs_joues', 'titularisations', 'minutes_jouees',
#        'matchs_90_minutes', 'buts_encaisses', 'buts_encaisses_par_90',
#        'tirs_cadres_subis', 'arrets', 'pourcentage_arrets', 'victoires',
#        'nuls', 'defaites', 'clean_sheets', 'pourcentage_clean_sheets',
#        'penaltys_tentes', 'penaltys_concedes', 'penaltys_arretes',
#        'penaltys_rates', 'pourcentage_arrets_penalty', 'cle_primaire',
#        'date_telechargement', 'theme'],
#       dtype='object')

# %%
joueurs_goal_shot_creation.columns = col_tirs_creation
joueurs_goal_shot_creation.columns
# Out:
# Index(['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age',
#        'annee_naissance', 'temps_90s', 'sca_total', 'sca_par_90',
#        'sca_passes_vives', 'sca_passes_mortes', 'sca_dribbles', 'sca_tirs',
#        'sca_fautes_subies', 'sca_actions_def', 'gca_total', 'gca_par_90',
#        'gca_passes_vives', 'gca_passes_mortes', 'gca_dribbles', 'gca_tirs',
#        'gca_fautes_subies', 'gca_actions_def', 'cle_primaire',
#        'date_telechargement', 'theme'],
#       dtype='object')

# %%
import nbformat
from nbconvert import PythonExporter

notebook_filename = "bdd_foot.ipynb"
script_filename = "bdd_foot.py"

with open(notebook_filename) as f:
    nb = nbformat.read(f, as_version=4)

exporter = PythonExporter()
source, _ = exporter.from_notebook_node(nb)

with open(script_filename, "w") as f:
    f.write(source)
