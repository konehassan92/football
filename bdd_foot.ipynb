# %% [markdown]
# # Librairies

# %%
import soccerdata as sd
import pandas as pd
from datetime import datetime, date, timedelta
import os
# Out:
# [08/09/25 02:42:37] INFO     No custom team name replacements found. You can configure these in       ]8;id=702311;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=861648;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\hassa\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=702215;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=275537;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_config.py#197\197]8;;\
#                              C:\Users\hassa\soccerdata\config\league_dict.json.

# %%
print(sd.FBref())

fbref = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=[2425])
print(fbref.__doc__)
# Out:
#                     INFO     Saving cached data to C:\Users\hassa\soccerdata\data\FBref              ]8;id=795234;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=48459;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py#263\263]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=55596;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=626866;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py#475\475]8;;\
# <soccerdata.fbref.FBref object at 0x00000244EC084F80>
#                     INFO     Saving cached data to C:\Users\hassa\soccerdata\data\FBref              ]8;id=460245;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=77399;file://C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\_common.py#263\263]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
#                       'http': 'http://10.10.1.10:3128',
#                       'https': 'http://10.10.1.10:1080',
#                   }
#
#             - list(dict): A list of proxies to choose from. A different proxy will
#               be selected from this list after failed requests, allowing rotating
#               proxies.
#             - callable: A function that returns a valid proxy. This function will
#               be called after failed requests, allowing rotating proxies.
#     no_cache : bool
#         If True, will not use cached data.
#     no_store : bool
#         If True, will not store downloaded data.
#     data_dir : Path
#         Path to directory where data will be cached.

# %% [markdown]
# # BDD

# %%
stat_joueurs = ['standard', 'keeper', 'keeper_adv', 'shooting', 'passing', 'passing_types', 
                'goal_shot_creation', 'defense', 'possession', 'playing_time', 'misc']
# Dictionnaire pour stocker les DataFrames
joueurs = {}

# Liste pour stocker les noms des tables créées
tables_crees = []


# Boucle pour traiter chaque thème/stat_joueurs
for theme in stat_joueurs:
    print(theme)
    
    # Lire les statistiques des joueurs
    joueurs[theme] = fbref.read_player_season_stats(stat_type=theme)
    
    # Modifier les colonnes du DataFrame
    joueurs[theme].columns = ['-'.join(filter(None, col)).strip() for col in joueurs[theme].columns.values]
    joueurs[theme].reset_index(inplace=True)
    joueurs[theme]["clé primaire"] = joueurs[theme]["player"].astype(str) + " - " + joueurs[theme]["team"].astype(str)
        
    # Renommer les DataFrames pour utilisation séparée dans le notebook
    globals()[f'joueurs_{theme}'] = joueurs[theme]

    # Ajouter le nom de la table à la liste des tables créées
    tables_crees.append(f'joueurs_{theme}')

# Afficher la liste des tables créées
print("Tables créées:", tables_crees)
# Out:
# standard
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=625755;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=656017;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# keeper
# [08/09/25 02:42:43] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=412473;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=501524;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# keeper_adv
# [08/09/25 02:42:44] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=760905;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=370826;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# shooting
# [08/09/25 02:42:45] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=469725;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=446579;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# passing
# [08/09/25 02:42:49] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=722853;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=841552;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# passing_types
# [08/09/25 02:42:54] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=486172;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=952642;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# goal_shot_creation
# [08/09/25 02:42:57] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=965610;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=380214;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# defense
# [08/09/25 02:43:01] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=915200;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=461737;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# possession
# [08/09/25 02:43:05] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=238134;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=57300;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# playing_time
# [08/09/25 02:43:10] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=311282;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=471616;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# misc
# [08/09/25 02:43:16] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=202217;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=698326;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Tables créées: ['joueurs_standard', 'joueurs_keeper', 'joueurs_keeper_adv', 'joueurs_shooting', 'joueurs_passing', 'joueurs_passing_types', 'joueurs_goal_shot_creation', 'joueurs_defense', 'joueurs_possession', 'joueurs_playing_time', 'joueurs_misc']

# %%
stat_equipes = ['standard', 'keeper', 'keeper_adv', 'shooting', 'passing', 'passing_types', 'goal_shot_creation', 'defense', 'possession', 'playing_time', 'misc']

# Dictionnaire pour stocker les DataFrames
equipes = {}
# Liste pour stocker les noms des tables créées
tables_crees = []

# Boucle pour traiter chaque thème/stat_joueur
for theme in stat_equipes:
    print(theme)
    
    # Lire les statistiques des joueurs
    equipes[theme] = fbref.read_team_season_stats(stat_type=theme)
    
    # Modifier les colonnes du DataFrame
    equipes[theme].columns = ['-'.join(filter(None, col)).strip() for col in equipes[theme].columns.values]
    equipes[theme].reset_index(inplace=True)

    # Afficher les informations du DataFrame
    print(equipes[theme].columns)
    print(equipes[theme].info())
    print(equipes[theme].shape)
    
    # Renommer les DataFrames pour utilisation séparée dans le notebook
    globals()[f'equipes_{theme}'] = equipes[theme]
    
    # Ajouter le nom de la table à la liste des tables créées
    tables_crees.append(f'equipes_{theme}')
    

# Afficher la liste des tables créées
print("Tables créées:", tables_crees)
# Out:
# standard
# [08/09/25 02:43:20] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=634055;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=474182;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', 'Age', 'Poss',
#        'Playing Time-MP', 'Playing Time-Starts', 'Playing Time-Min',
#        'Playing Time-90s', 'Performance-Gls', 'Performance-Ast',
#        'Performance-G+A', 'Performance-G-PK', 'Performance-PK',
#        'Performance-PKatt', 'Performance-CrdY', 'Performance-CrdR',
#        'Expected-xG', 'Expected-npxG', 'Expected-xAG', 'Expected-npxG+xAG',
#        'Progression-PrgC', 'Progression-PrgP', 'Per 90 Minutes-Gls',
#        'Per 90 Minutes-Ast', 'Per 90 Minutes-G+A', 'Per 90 Minutes-G-PK',
#        'Per 90 Minutes-G+A-PK', 'Per 90 Minutes-xG', 'Per 90 Minutes-xAG',
#        'Per 90 Minutes-xG+xAG', 'Per 90 Minutes-npxG',
#        'Per 90 Minutes-npxG+xAG', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   league                   96 non-null     object
#  1   season                   96 non-null     object
#  2   team                     96 non-null     string
#  3   players_used             96 non-null     Int64
#  4   Age                      96 non-null     Float64
#  5   Poss                     96 non-null     Float64
#  6   Playing Time-MP          96 non-null     Int64
#  7   Playing Time-Starts      96 non-null     Int64
#  8   Playing Time-Min         96 non-null     Int64
#  9   Playing Time-90s         96 non-null     Float64
#  10  Performance-Gls          96 non-null     Int64
#  11  Performance-Ast          96 non-null     Int64
#  12  Performance-G+A          96 non-null     Int64
#  13  Performance-G-PK         96 non-null     Int64
#  14  Performance-PK           96 non-null     Int64
#  15  Performance-PKatt        96 non-null     Int64
#  16  Performance-CrdY         96 non-null     Int64
#  17  Performance-CrdR         96 non-null     Int64
#  18  Expected-xG              96 non-null     Float64
#  19  Expected-npxG            96 non-null     Float64
#  20  Expected-xAG             96 non-null     Float64
#  21  Expected-npxG+xAG        96 non-null     Float64
#  22  Progression-PrgC         96 non-null     Int64
#  23  Progression-PrgP         96 non-null     Int64
#  24  Per 90 Minutes-Gls       96 non-null     Float64
#  25  Per 90 Minutes-Ast       96 non-null     Float64
#  26  Per 90 Minutes-G+A       96 non-null     Float64
#  27  Per 90 Minutes-G-PK      96 non-null     Float64
#  28  Per 90 Minutes-G+A-PK    96 non-null     Float64
#  29  Per 90 Minutes-xG        96 non-null     Float64
#  30  Per 90 Minutes-xAG       96 non-null     Float64
#  31  Per 90 Minutes-xG+xAG    96 non-null     Float64
#  32  Per 90 Minutes-npxG      96 non-null     Float64
#  33  Per 90 Minutes-npxG+xAG  96 non-null     Float64
#  34  url                      96 non-null     object
# dtypes: Float64(17), Int64(14), object(3), string(1)
# memory usage: 29.3+ KB
# None
# (96, 35)
# keeper
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=74106;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=623685;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', 'Playing Time-MP',
#        'Playing Time-Starts', 'Playing Time-Min', '90s', 'Performance-GA',
#        'Performance-GA90', 'Performance-SoTA', 'Performance-Saves',
#        'Performance-Save%', 'Performance-W', 'Performance-D', 'Performance-L',
#        'Performance-CS', 'Performance-CS%', 'Penalty Kicks-PKatt',
#        'Penalty Kicks-PKA', 'Penalty Kicks-PKsv', 'Penalty Kicks-PKm',
#        'Penalty Kicks-Save%', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   league               96 non-null     object
#  1   season               96 non-null     object
#  2   team                 96 non-null     string
#  3   players_used         96 non-null     Int64
#  4   Playing Time-MP      96 non-null     Int64
#  5   Playing Time-Starts  96 non-null     Int64
#  6   Playing Time-Min     96 non-null     Int64
#  7   90s                  96 non-null     Float64
#  8   Performance-GA       96 non-null     Int64
#  9   Performance-GA90     96 non-null     Float64
#  10  Performance-SoTA     96 non-null     Int64
#  11  Performance-Saves    96 non-null     Int64
#  12  Performance-Save%    96 non-null     Float64
#  13  Performance-W        96 non-null     Int64
#  14  Performance-D        96 non-null     Int64
#  15  Performance-L        96 non-null     Int64
#  16  Performance-CS       96 non-null     Int64
#  17  Performance-CS%      96 non-null     Float64
#  18  Penalty Kicks-PKatt  96 non-null     Int64
#  19  Penalty Kicks-PKA    96 non-null     Int64
#  20  Penalty Kicks-PKsv   96 non-null     Int64
#  21  Penalty Kicks-PKm    96 non-null     Int64
#  22  Penalty Kicks-Save%  95 non-null     Float64
#  23  url                  96 non-null     object
# dtypes: Float64(5), Int64(15), object(3), string(1)
# memory usage: 20.0+ KB
# None
# (96, 24)
# keeper_adv
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=239403;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=665578;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'Goals-GA',
#        'Goals-PKA', 'Goals-FK', 'Goals-CK', 'Goals-OG', 'Expected-PSxG',
#        'Expected-PSxG/SoT', 'Expected-PSxG+/-', 'Expected-/90', 'Launched-Cmp',
#        'Launched-Att', 'Launched-Cmp%', 'Passes-Att (GK)', 'Passes-Thr',
#        'Passes-Launch%', 'Passes-AvgLen', 'Goal Kicks-Att',
#        'Goal Kicks-Launch%', 'Goal Kicks-AvgLen', 'Crosses-Opp', 'Crosses-Stp',
#        'Crosses-Stp%', 'Sweeper-#OPA', 'Sweeper-#OPA/90', 'Sweeper-AvgDist',
#        'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   league              96 non-null     object
#  1   season              96 non-null     object
#  2   team                96 non-null     string
#  3   players_used        96 non-null     Int64
#  4   90s                 96 non-null     Float64
#  5   Goals-GA            96 non-null     Int64
#  6   Goals-PKA           96 non-null     Int64
#  7   Goals-FK            96 non-null     Int64
#  8   Goals-CK            96 non-null     Int64
#  9   Goals-OG            96 non-null     Int64
#  10  Expected-PSxG       96 non-null     Float64
#  11  Expected-PSxG/SoT   96 non-null     Float64
#  12  Expected-PSxG+/-    96 non-null     Float64
#  13  Expected-/90        96 non-null     Float64
#  14  Launched-Cmp        96 non-null     Int64
#  15  Launched-Att        96 non-null     Int64
#  16  Launched-Cmp%       96 non-null     Float64
#  17  Passes-Att (GK)     96 non-null     Int64
#  18  Passes-Thr          96 non-null     Int64
#  19  Passes-Launch%      96 non-null     Float64
#  20  Passes-AvgLen       96 non-null     Float64
#  21  Goal Kicks-Att      96 non-null     Int64
#  22  Goal Kicks-Launch%  96 non-null     Float64
#  23  Goal Kicks-AvgLen   96 non-null     Float64
#  24  Crosses-Opp         96 non-null     Int64
#  25  Crosses-Stp         96 non-null     Int64
#  26  Crosses-Stp%        96 non-null     Float64
#  27  Sweeper-#OPA        96 non-null     Int64
#  28  Sweeper-#OPA/90     96 non-null     Float64
#  29  Sweeper-AvgDist     96 non-null     Float64
#  30  url                 96 non-null     object
# dtypes: Float64(13), Int64(14), object(3), string(1)
# memory usage: 25.9+ KB
# None
# (96, 31)
# shooting
# [08/09/25 02:43:21] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=213332;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=91547;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'Standard-Gls',
#        'Standard-Sh', 'Standard-SoT', 'Standard-SoT%', 'Standard-Sh/90',
#        'Standard-SoT/90', 'Standard-G/Sh', 'Standard-G/SoT', 'Standard-Dist',
#        'Standard-FK', 'Standard-PK', 'Standard-PKatt', 'Expected-xG',
#        'Expected-npxG', 'Expected-npxG/Sh', 'Expected-G-xG',
#        'Expected-np:G-xG', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   league            96 non-null     object
#  1   season            96 non-null     object
#  2   team              96 non-null     string
#  3   players_used      96 non-null     Int64
#  4   90s               96 non-null     Float64
#  5   Standard-Gls      96 non-null     Int64
#  6   Standard-Sh       96 non-null     Int64
#  7   Standard-SoT      96 non-null     Int64
#  8   Standard-SoT%     96 non-null     Float64
#  9   Standard-Sh/90    96 non-null     Float64
#  10  Standard-SoT/90   96 non-null     Float64
#  11  Standard-G/Sh     96 non-null     Float64
#  12  Standard-G/SoT    96 non-null     Float64
#  13  Standard-Dist     96 non-null     Float64
#  14  Standard-FK       96 non-null     Int64
#  15  Standard-PK       96 non-null     Int64
#  16  Standard-PKatt    96 non-null     Int64
#  17  Expected-xG       96 non-null     Float64
#  18  Expected-npxG     96 non-null     Float64
#  19  Expected-npxG/Sh  96 non-null     Float64
#  20  Expected-G-xG     96 non-null     Float64
#  21  Expected-np:G-xG  96 non-null     Float64
#  22  url               96 non-null     object
# dtypes: Float64(12), Int64(7), object(3), string(1)
# memory usage: 19.2+ KB
# None
# (96, 23)
# passing
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=233515;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=629091;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'Total-Cmp',
#        'Total-Att', 'Total-Cmp%', 'Total-TotDist', 'Total-PrgDist',
#        'Short-Cmp', 'Short-Att', 'Short-Cmp%', 'Medium-Cmp', 'Medium-Att',
#        'Medium-Cmp%', 'Long-Cmp', 'Long-Att', 'Long-Cmp%', 'Ast', 'xAG',
#        'Expected-xA', 'Expected-A-xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'PrgP',
#        'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   league          96 non-null     object
#  1   season          96 non-null     object
#  2   team            96 non-null     string
#  3   players_used    96 non-null     Int64
#  4   90s             96 non-null     Float64
#  5   Total-Cmp       96 non-null     Int64
#  6   Total-Att       96 non-null     Int64
#  7   Total-Cmp%      96 non-null     Float64
#  8   Total-TotDist   96 non-null     Int64
#  9   Total-PrgDist   96 non-null     Int64
#  10  Short-Cmp       96 non-null     Int64
#  11  Short-Att       96 non-null     Int64
#  12  Short-Cmp%      96 non-null     Float64
#  13  Medium-Cmp      96 non-null     Int64
#  14  Medium-Att      96 non-null     Int64
#  15  Medium-Cmp%     96 non-null     Float64
#  16  Long-Cmp        96 non-null     Int64
#  17  Long-Att        96 non-null     Int64
#  18  Long-Cmp%       96 non-null     Float64
#  19  Ast             96 non-null     Int64
#  20  xAG             96 non-null     Float64
#  21  Expected-xA     96 non-null     Float64
#  22  Expected-A-xAG  96 non-null     Float64
#  23  KP              96 non-null     Int64
#  24  1/3             96 non-null     Int64
#  25  PPA             96 non-null     Int64
#  26  CrsPA           96 non-null     Int64
#  27  PrgP            96 non-null     Int64
#  28  url             96 non-null     object
# dtypes: Float64(8), Int64(17), object(3), string(1)
# memory usage: 24.2+ KB
# None
# (96, 29)
# passing_types
# [08/09/25 02:43:22] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=87053;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=217668;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'Att',
#        'Pass Types-Live', 'Pass Types-Dead', 'Pass Types-FK', 'Pass Types-TB',
#        'Pass Types-Sw', 'Pass Types-Crs', 'Pass Types-TI', 'Pass Types-CK',
#        'Corner Kicks-In', 'Corner Kicks-Out', 'Corner Kicks-Str',
#        'Outcomes-Cmp', 'Outcomes-Off', 'Outcomes-Blocks', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   league            96 non-null     object
#  1   season            96 non-null     object
#  2   team              96 non-null     string
#  3   players_used      96 non-null     Int64
#  4   90s               96 non-null     Float64
#  5   Att               96 non-null     Int64
#  6   Pass Types-Live   96 non-null     Int64
#  7   Pass Types-Dead   96 non-null     Int64
#  8   Pass Types-FK     96 non-null     Int64
#  9   Pass Types-TB     96 non-null     Int64
#  10  Pass Types-Sw     96 non-null     Int64
#  11  Pass Types-Crs    96 non-null     Int64
#  12  Pass Types-TI     96 non-null     Int64
#  13  Pass Types-CK     96 non-null     Int64
#  14  Corner Kicks-In   96 non-null     Int64
#  15  Corner Kicks-Out  96 non-null     Int64
#  16  Corner Kicks-Str  96 non-null     Int64
#  17  Outcomes-Cmp      96 non-null     Int64
#  18  Outcomes-Off      96 non-null     Int64
#  19  Outcomes-Blocks   96 non-null     Int64
#  20  url               96 non-null     object
# dtypes: Float64(1), Int64(16), object(3), string(1)
# memory usage: 17.5+ KB
# None
# (96, 21)
# goal_shot_creation
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=137061;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=744856;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'SCA-SCA',
#        'SCA-SCA90', 'SCA Types-PassLive', 'SCA Types-PassDead', 'SCA Types-TO',
#        'SCA Types-Sh', 'SCA Types-Fld', 'SCA Types-Def', 'GCA-GCA',
#        'GCA-GCA90', 'GCA Types-PassLive', 'GCA Types-PassDead', 'GCA Types-TO',
#        'GCA Types-Sh', 'GCA Types-Fld', 'GCA Types-Def', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   league              96 non-null     object
#  1   season              96 non-null     object
#  2   team                96 non-null     string
#  3   players_used        96 non-null     Int64
#  4   90s                 96 non-null     Float64
#  5   SCA-SCA             96 non-null     Int64
#  6   SCA-SCA90           96 non-null     Float64
#  7   SCA Types-PassLive  96 non-null     Int64
#  8   SCA Types-PassDead  96 non-null     Int64
#  9   SCA Types-TO        96 non-null     Int64
#  10  SCA Types-Sh        96 non-null     Int64
#  11  SCA Types-Fld       96 non-null     Int64
#  12  SCA Types-Def       96 non-null     Int64
#  13  GCA-GCA             96 non-null     Int64
#  14  GCA-GCA90           96 non-null     Float64
#  15  GCA Types-PassLive  96 non-null     Int64
#  16  GCA Types-PassDead  96 non-null     Int64
#  17  GCA Types-TO        96 non-null     Int64
#  18  GCA Types-Sh        96 non-null     Int64
#  19  GCA Types-Fld       96 non-null     Int64
#  20  GCA Types-Def       96 non-null     Int64
#  21  url                 96 non-null     object
# dtypes: Float64(3), Int64(15), object(3), string(1)
# memory usage: 18.3+ KB
# None
# (96, 22)
# defense
# [08/09/25 02:43:23] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=748521;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=86723;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'Tackles-Tkl',
#        'Tackles-TklW', 'Tackles-Def 3rd', 'Tackles-Mid 3rd', 'Tackles-Att 3rd',
#        'Challenges-Tkl', 'Challenges-Att', 'Challenges-Tkl%',
#        'Challenges-Lost', 'Blocks-Blocks', 'Blocks-Sh', 'Blocks-Pass', 'Int',
#        'Tkl+Int', 'Clr', 'Err', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   league           96 non-null     object
#  1   season           96 non-null     object
#  2   team             96 non-null     string
#  3   players_used     96 non-null     Int64
#  4   90s              96 non-null     Float64
#  5   Tackles-Tkl      96 non-null     Int64
#  6   Tackles-TklW     96 non-null     Int64
#  7   Tackles-Def 3rd  96 non-null     Int64
#  8   Tackles-Mid 3rd  96 non-null     Int64
#  9   Tackles-Att 3rd  96 non-null     Int64
#  10  Challenges-Tkl   96 non-null     Int64
#  11  Challenges-Att   96 non-null     Int64
#  12  Challenges-Tkl%  96 non-null     Float64
#  13  Challenges-Lost  96 non-null     Int64
#  14  Blocks-Blocks    96 non-null     Int64
#  15  Blocks-Sh        96 non-null     Int64
#  16  Blocks-Pass      96 non-null     Int64
#  17  Int              96 non-null     Int64
#  18  Tkl+Int          96 non-null     Int64
#  19  Clr              96 non-null     Int64
#  20  Err              96 non-null     Int64
#  21  url              96 non-null     object
# dtypes: Float64(2), Int64(16), object(3), string(1)
# memory usage: 18.3+ KB
# None
# (96, 22)
# possession
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=852327;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=185620;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', 'Poss', '90s',
#        'Touches-Touches', 'Touches-Def Pen', 'Touches-Def 3rd',
#        'Touches-Mid 3rd', 'Touches-Att 3rd', 'Touches-Att Pen', 'Touches-Live',
#        'Take-Ons-Att', 'Take-Ons-Succ', 'Take-Ons-Succ%', 'Take-Ons-Tkld',
#        'Take-Ons-Tkld%', 'Carries-Carries', 'Carries-TotDist',
#        'Carries-PrgDist', 'Carries-PrgC', 'Carries-1/3', 'Carries-CPA',
#        'Carries-Mis', 'Carries-Dis', 'Receiving-Rec', 'Receiving-PrgR', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   league           96 non-null     object
#  1   season           96 non-null     object
#  2   team             96 non-null     string
#  3   players_used     96 non-null     Int64
#  4   Poss             96 non-null     Float64
#  5   90s              96 non-null     Float64
#  6   Touches-Touches  96 non-null     Int64
#  7   Touches-Def Pen  96 non-null     Int64
#  8   Touches-Def 3rd  96 non-null     Int64
#  9   Touches-Mid 3rd  96 non-null     Int64
#  10  Touches-Att 3rd  96 non-null     Int64
#  11  Touches-Att Pen  96 non-null     Int64
#  12  Touches-Live     96 non-null     Int64
#  13  Take-Ons-Att     96 non-null     Int64
#  14  Take-Ons-Succ    96 non-null     Int64
#  15  Take-Ons-Succ%   96 non-null     Float64
#  16  Take-Ons-Tkld    96 non-null     Int64
#  17  Take-Ons-Tkld%   96 non-null     Float64
#  18  Carries-Carries  96 non-null     Int64
#  19  Carries-TotDist  96 non-null     Int64
#  20  Carries-PrgDist  96 non-null     Int64
#  21  Carries-PrgC     96 non-null     Int64
#  22  Carries-1/3      96 non-null     Int64
#  23  Carries-CPA      96 non-null     Int64
#  24  Carries-Mis      96 non-null     Int64
#  25  Carries-Dis      96 non-null     Int64
#  26  Receiving-Rec    96 non-null     Int64
#  27  Receiving-PrgR   96 non-null     Int64
#  28  url              96 non-null     object
# dtypes: Float64(4), Int64(21), object(3), string(1)
# memory usage: 24.2+ KB
# None
# (96, 29)
# playing_time
# [08/09/25 02:43:24] WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=296726;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=503916;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', 'Age', 'Playing Time-MP',
#        'Playing Time-Min', 'Playing Time-Mn/MP', 'Playing Time-Min%',
#        'Playing Time-90s', 'Starts-Starts', 'Starts-Mn/Start', 'Starts-Compl',
#        'Subs-Subs', 'Subs-Mn/Sub', 'Subs-unSub', 'Team Success-PPM',
#        'Team Success-onG', 'Team Success-onGA', 'Team Success-+/-',
#        'Team Success-+/-90', 'Team Success (xG)-onxG',
#        'Team Success (xG)-onxGA', 'Team Success (xG)-xG+/-',
#        'Team Success (xG)-xG+/-90', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   league                     96 non-null     object
#  1   season                     96 non-null     object
#  2   team                       96 non-null     string
#  3   players_used               96 non-null     Int64
#  4   Age                        96 non-null     Float64
#  5   Playing Time-MP            96 non-null     Int64
#  6   Playing Time-Min           96 non-null     Int64
#  7   Playing Time-Mn/MP         96 non-null     Int64
#  8   Playing Time-Min%          96 non-null     Int64
#  9   Playing Time-90s           96 non-null     Float64
#  10  Starts-Starts              96 non-null     Int64
#  11  Starts-Mn/Start            96 non-null     Int64
#  12  Starts-Compl               96 non-null     Int64
#  13  Subs-Subs                  96 non-null     Int64
#  14  Subs-Mn/Sub                96 non-null     Int64
#  15  Subs-unSub                 96 non-null     Int64
#  16  Team Success-PPM           96 non-null     Float64
#  17  Team Success-onG           96 non-null     Int64
#  18  Team Success-onGA          96 non-null     Int64
#  19  Team Success-+/-           96 non-null     Int64
#  20  Team Success-+/-90         96 non-null     Float64
#  21  Team Success (xG)-onxG     96 non-null     Float64
#  22  Team Success (xG)-onxGA    96 non-null     Float64
#  23  Team Success (xG)-xG+/-    96 non-null     Float64
#  24  Team Success (xG)-xG+/-90  96 non-null     Float64
#  25  url                        96 non-null     object
# dtypes: Float64(8), Int64(14), object(3), string(1)
# memory usage: 21.7+ KB
# None
# (96, 26)
# misc
#                     WARNING  C:\Users\hassa\anaconda3\Lib\site-packages\soccerdata\fbref.py:165:    ]8;id=151539;file://C:\Users\hassa\anaconda3\Lib\warnings.py\warnings.py]8;;\:]8;id=896709;file://C:\Users\hassa\anaconda3\Lib\warnings.py#112\112]8;;\
#                              FutureWarning: The behavior of DataFrame concatenation with empty or
#                              all-NA entries is deprecated. In a future version, this will no longer
#                              exclude empty or all-NA columns when determining the result dtypes. To
#                              retain the old behavior, exclude the relevant entries before the
#                              concat operation.
#                                pd.concat(dfs)
# Index(['league', 'season', 'team', 'players_used', '90s', 'Performance-CrdY',
#        'Performance-CrdR', 'Performance-2CrdY', 'Performance-Fls',
#        'Performance-Fld', 'Performance-Off', 'Performance-Crs',
#        'Performance-Int', 'Performance-TklW', 'Performance-PKwon',
#        'Performance-PKcon', 'Performance-OG', 'Performance-Recov',
#        'Aerial Duels-Won', 'Aerial Duels-Lost', 'Aerial Duels-Won%', 'url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   league             96 non-null     object
#  1   season             96 non-null     object
#  2   team               96 non-null     string
#  3   players_used       96 non-null     Int64
#  4   90s                96 non-null     Float64
#  5   Performance-CrdY   96 non-null     Int64
#  6   Performance-CrdR   96 non-null     Int64
#  7   Performance-2CrdY  96 non-null     Int64
#  8   Performance-Fls    96 non-null     Int64
#  9   Performance-Fld    96 non-null     Int64
#  10  Performance-Off    96 non-null     Int64
#  11  Performance-Crs    96 non-null     Int64
#  12  Performance-Int    96 non-null     Int64
#  13  Performance-TklW   96 non-null     Int64
#  14  Performance-PKwon  96 non-null     Int64
#  15  Performance-PKcon  96 non-null     Int64
#  16  Performance-OG     96 non-null     Int64
#  17  Performance-Recov  96 non-null     Int64
#  18  Aerial Duels-Won   96 non-null     Int64
#  19  Aerial Duels-Lost  96 non-null     Int64
#  20  Aerial Duels-Won%  96 non-null     Float64
#  21  url                96 non-null     object
# dtypes: Float64(2), Int64(16), object(3), string(1)
# memory usage: 18.3+ KB
# None
# (96, 22)
# Tables créées: ['equipes_standard', 'equipes_keeper', 'equipes_keeper_adv', 'equipes_shooting', 'equipes_passing', 'equipes_passing_types', 'equipes_goal_shot_creation', 'equipes_defense', 'equipes_possession', 'equipes_playing_time', 'equipes_misc']

# %% [markdown]
# # Nettoyage

# %% [markdown]
# ##### Nom des nouvelles colonnes

# %%
col_standard = [
    "ligue",                      # inchangé
    "saison",                      # inchangé
    "equipe",                        # inchangé
    "joueur",                      # inchangé
    "nationalite",                 # 'nation'
    "poste",                       # 'pos'
    "age",                         # 'age'
    "annee_naissance",            # 'born'

    # Temps de jeu
    "matchs_joues",               # 'Playing Time-MP'
    "titularisations",            # 'Playing Time-Starts'
    "minutes_jouees",            # 'Playing Time-Min'
    "matchs_90_minutes",         # 'Playing Time-90s'

    # Performance
    "buts",                       # 'Performance-Gls'
    "passes_decisives",          # 'Performance-Ast'
    "buts_plus_passes",          # 'Performance-G+A'
    "buts_hors_penalty",         # 'Performance-G-PK'
    "penaltys_marques",          # 'Performance-PK'
    "penaltys_tentes",           # 'Performance-PKatt'
    "cartons_jaunes",            # 'Performance-CrdY'
    "cartons_rouges",            # 'Performance-CrdR'

    # Expected (statistiques attendues)
    "buts_attendus",                         # 'Expected-xG'
    "buts_attendus_hors_penalty",           # 'Expected-npxG'
    "passes_attendues",                     # 'Expected-xAG'
    "buts_hors_penalty_plus_passes_attendues", # 'Expected-npxG+xAG'

    # Progression
    "conduites_progressives",     # 'Progression-PrgC'
    "passes_progressives",        # 'Progression-PrgP'
    "passes_progressives_recues", # 'Progression-PrgR'

    # Par 90 minutes
    "buts_par_90",                              # 'Per 90 Minutes-Gls'
    "passes_decisives_par_90",                 # 'Per 90 Minutes-Ast'
    "buts_plus_passes_par_90",                 # 'Per 90 Minutes-G+A'
    "buts_hors_penalty_par_90",                # 'Per 90 Minutes-G-PK'
    "buts_plus_passes_hors_penalty_par_90",    # 'Per 90 Minutes-G+A-PK'
    "buts_attendus_par_90",                    # 'Per 90 Minutes-xG'
    "passes_attendues_par_90",                 # 'Per 90 Minutes-xAG'
    "buts_plus_passes_attendues_par_90",       # 'Per 90 Minutes-xG+xAG'
    "buts_attendus_hors_penalty_par_90",       # 'Per 90 Minutes-npxG'
    "buts_hors_penalty_plus_passes_attendues_90", # 'Per 90 Minutes-npxG+xAG'

    # Autres
    "cle_primaire",               # 'clé primaire'
]


col_gardien = [
    "ligue",                          # inchangé
    "saison",                          # inchangé
    "equipe",                            # inchangé
    "joueur",                          # inchangé
    "nationalite",                     # nation
    "poste",                           # pos
    "age",                             # age
    "annee_naissance",                # born

    # Temps de jeu
    "matchs_joues",                   # Playing Time-MP
    "titularisations",                # Playing Time-Starts
    "minutes_jouees",                # Playing Time-Min
    "matchs_90_minutes",             # 90s

    # Performance défensive gardien
    "buts_encaisses",                # Performance-GA
    "buts_encaisses_par_90",        # Performance-GA90
    "tirs_cadres_subis",            # Performance-SoTA
    "arrets",                        # Performance-Saves
    "pourcentage_arrets",           # Performance-Save%
    "victoires",                     # Performance-W
    "nuls",                          # Performance-D
    "defaites",                      # Performance-L
    "clean_sheets",                 # Performance-CS
    "pourcentage_clean_sheets",    # Performance-CS%

    # Penaltys
    "penaltys_tentes",              # Penalty Kicks-PKatt
    "penaltys_concedes",           # Penalty Kicks-PKA
    "penaltys_arretes",            # Penalty Kicks-PKsv
    "penaltys_rates",              # Penalty Kicks-PKm
    "pourcentage_arrets_penalty", # Penalty Kicks-Save%

    # Métadonnées
    "cle_primaire",                 # clé primaire
]


col_actions_creation = [
    "ligue",                      # Ligue
    "saison",                     # Saison
    "equipe",                     # Équipe
    "joueur",                     # Joueur
    "nationalite",                # Nationalité
    "poste",                      # Poste
    "age",                        # Âge
    "annee_naissance",            # Année de naissance
    "temps_90s",                  # Temps de jeu en équivalent 90 minutes

    # Actions menant à un tir
    "action_tir_total",           # Total d’actions menant à un tir
    "action_tir_par_90",          # Actions menant à un tir par 90 minutes
    "action_tir_passes_vives",    # Passes en jeu menant à un tir
    "action_tir_passes_mortes",   # Passes arrêtées menant à un tir
    "action_tir_dribbles",        # Dribbles menant à un tir
    "action_tir_tirs",            # Tirs menant à un autre tir
    "action_tir_fautes_subies",   # Fautes subies menant à un tir
    "action_tir_actions_def",     # Actions défensives menant à un tir

    # Actions menant à un but
    "action_but_total",           # Total d’actions menant à un but
    "action_but_par_90",          # Actions menant à un but par 90 minutes
    "action_but_passes_vives",    # Passes en jeu menant à un but
    "action_but_passes_mortes",   # Passes arrêtées menant à un but
    "action_but_dribbles",        # Dribbles menant à un but
    "action_but_tirs",            # Tirs menant à un but
    "action_but_fautes_subies",   # Fautes subies menant à un but
    "action_but_actions_def",     # Actions défensives menant à un but

    # Autres colonnes techniques
    "cle_primaire",               # Clé primaire
]

col_gardiens_1 = [
    "ligue",                   # league
    "saison",                  # season
    "equipe",                  # team
    "joueur",                  # player
    "nationalite",             # nation
    "poste",                   # pos
    "age",                     # age
    "annee_naissance",         # born
    "temps_90s",               # 90s

    # Buts concédés
    "buts_encaisses",          # Goals-GA
    "penaltys_encaisses",      # Goals-PKA
    "coup_francs_encaisses",   # Goals-FK
    "corners_encaisses",       # Goals-CK
    "csc_encaisses",           # Goals-OG

    # Indicateurs Buts Attendues Après Tir (PSxG)
    "buts_att_ps",                # Buts attendus après tir (probabilité d'arrêt du gardien)
    "buts_att_ps_par_tir_cadre",  # Buts attendus après tir par tir cadré (difficulté des arrêts)
    "diff_buts_att_ps_encaisses", # Différence entre buts attendus après tir et buts encaissés (efficacité du gardien)
    "diff_buts_att_ps_encaisses_90", # Différence PSxG - buts encaissés par 90 min (performance normalisée)

    # Passes longues (lancées)
    "passes_longues_reussies", # Launched-Cmp
    "passes_longues_tentees",  # Launched-Att
    "passes_longues_pct",      # Launched-Cmp%

    # Passes du gardien
    "passes_tentees_gk",       # Passes-Att (GK)
    "remises_a_la_main",       # Passes-Thr
    "passes_lance_pct",        # Passes-Launch%
    "longueur_moyenne_passe",  # Passes-AvgLen

    # Dégagements au pied (goal kicks)
    "degagements_tentes",      # Goal Kicks-Att
    "degagements_pct_longs",   # Goal Kicks-Launch%
    "longueur_moyenne_degagement", # Goal Kicks-AvgLen

    # Centres subis
    "centres_subis",           # Crosses-Opp
    "centres_interceptes",     # Crosses-Stp
    "centres_interceptes_pct", # Crosses-Stp%

    # Gardien-libéro (Sweeper)
    "actions_def_hors_surface",      # Sweeper-#OPA
    "actions_def_hors_surface_par90",# Sweeper-#OPA/90
    "distance_moy_actions_def",      # Sweeper-AvgDist

    # Colonnes générales
    "cle_primaire",            # clé primaire
]


col_tirs = [
    "ligue",                 # league
    "saison",                # season
    "equipe",                # team
    "joueur",                # player
    "nationalite",           # nation
    "poste",                 # pos
    "age",                   # age
    "annee_naissance",       # born
    "temps_90s",             # 90s

    # Statistiques Standard de tirs
    "buts",                  # Standard-Gls (Buts marqués)
    "tirs_totaux",           # Standard-Sh (Tirs totaux, sans pénaltys)
    "tirs_cadres",           # Standard-SoT (Tirs cadrés, sans pénaltys)
    "pct_tirs_cadres",       # Standard-SoT% (Pourcentage de tirs cadrés)
    "tirs_par_90",           # Standard-Sh/90 (Tirs totaux par 90 minutes)
    "tirs_cadres_par_90",    # Standard-SoT/90 (Tirs cadrés par 90 minutes)
    "buts_par_tir",          # Standard-G/Sh (Buts par tir)
    "buts_par_tir_cadre",    # Standard-G/SoT (Buts par tir cadré)
    "distance_moy_tir",      # Standard-Dist (Distance moyenne des tirs en yards)
    "tirs_coup_franc",       # Standard-FK (Tirs sur coups francs)
    "penaltys_marques",      # Standard-PK (Pénaltys marqués)
    "penaltys_tentes",       # Standard-PKatt (Pénaltys tentés)

    # Indicateurs attendus (Expected)
    "buts_attendus_xg",          # Expected-xG (Buts attendus)
    "buts_attendus_np_xg",       # Expected-npxG (Buts attendus hors pénaltys)
    "buts_attendus_np_xg_par_tir", # Expected-npxG/Sh (Buts attendus hors pénaltys par tir)
    "diff_buts_buts_attendus",   # Expected-G-xG (Différence buts réels - buts attendus)
    "diff_buts_np_buts_attendus",# Expected-np:G-xG (Différence buts hors pénaltys - buts attendus hors pénaltys)

    # Colonnes générales
    "cle_primaire",          # clé primaire
]


col_passes = [
    "ligue",                  # league
    "saison",                 # season
    "equipe",                 # team
    "joueur",                 # player
    "nationalite",            # nation
    "poste",                  # pos
    "age",                    # age
    "annee_naissance",        # born
    "temps_90s",              # 90s Joué (minutes jouées divisées par 90)

    # Passes totales
    "passes_reussies",        # Total-Cmp : Passes réussies (y compris centres, corners, touches, coups francs, dégagements)
    "passes_tentees",         # Total-Att : Passes tentées (idem)
    "pct_reussite_passes",    # Total-Cmp% : Pourcentage de passes réussies (minimum 30 minutes jouées)
    "distance_totale_passes", # Total-TotDist : Distance totale parcourue par les passes réussies (en yards)
    "distance_progressive",   # Total-PrgDist : Distance progressive vers le but adverse des passes réussies (en yards)

    # Passes courtes (5 à 15 yards)
    "passes_courtes_reussies", # Short-Cmp : Passes courtes réussies
    "passes_courtes_tentees",  # Short-Att : Passes courtes tentées
    "pct_reussite_courtes",    # Short-Cmp% : % réussite passes courtes (minimum 30 minutes jouées)

    # Passes moyennes (15 à 30 yards)
    "passes_moyennes_reussies", # Medium-Cmp : Passes moyennes réussies
    "passes_moyennes_tentees",  # Medium-Att : Passes moyennes tentées
    "pct_reussite_moyennes",    # Medium-Cmp% : % réussite passes moyennes (minimum 30 minutes jouées)

    # Passes longues (> 30 yards)
    "passes_longues_reussies",  # Long-Cmp : Passes longues réussies
    "passes_longues_tentees",   # Long-Att : Passes longues tentées
    "pct_reussite_longues",     # Long-Cmp% : % réussite passes longues (minimum 30 minutes jouées)

    # Passes décisives et expected assists
    "passes_decisives",         # Ast : Passes décisives
    "buts_attendus_passe_decisive", # xAG : Buts attendus suite à une passe décisive
    "passes_attendues",         # Expected-xA : Passes attendues (probabilité d’assister un but)
    "diff_passes_decisives_attendues", # Expected-A-xAG : Différence passes décisives et passes attendues

    # Passes clés et progression
    "passes_cles",             # KP : Passes clés menant directement à un tir
    "passes_dans_tiers_final", # 1/3 : Passes complétées dans le dernier tiers du terrain (hors coups francs)
    "passes_dans_surface_penalite", # PPA : Passes dans la surface de réparation (hors coups francs)
    "centres_dans_surface_penalite", # CrsPA : Centres dans la surface (hors coups francs)
    "passes_progressives",     # PrgP : Passes progressives vers le but adverse (au moins 10 yards ou dans la surface)

    # Colonnes générales
    "cle_primaire",            # clé primaire
]


col_pass_types = [
    "ligue",                  # league
    "saison",                 # season
    "equipe",                 # team
    "joueur",                 # player
    "nationalite",            # nation
    "poste",                  # pos
    "age",                    # age
    "annee_naissance",        # born
    "temps_90s",              # 90s (minutes jouées divisées par 90)

    # Passes tentées
    "passes_tentees",         # Att : Passes tentées (inclut passes en jeu, corners, touches, coups francs, dégagements)

    # Types de passes
    "passes_vives",           # Pass Types-Live : Passes en jeu (live-ball passes)
    "passes_mortes",          # Pass Types-Dead : Passes arrêtées (dead-ball passes, ex : coups francs, corners, touches, dégagements)
    "passes_coups_francs",    # Pass Types-FK : Passes tentées sur coups francs
    "passes_passees_en_rupture", # Pass Types-TB : Passes en profondeur (through balls)
    "passes_deviation_large", # Pass Types-Sw : Passes transversales (> 40 yards de largeur)
    "centres",                # Pass Types-Crs : Centres
    "touches_reprises",       # Pass Types-TI : Touches de balle (throw-ins)
    "corners_tentes",         # Pass Types-CK : Corners tentés

    # Corners - type
    "corners_entrant",        # Corner Kicks-In : Corners rentrants (inswinging)
    "corners_sortant",        # Corner Kicks-Out : Corners sortants (outswinging)
    "corners_droits",         # Corner Kicks-Str : Corners directs (straight)

    # Résultats des passes
    "passes_reussies",        # Outcomes-Cmp : Passes réussies (inclut tous types)
    "passes_hors_jeu",        # Outcomes-Off : Passes hors-jeu
    "passes_bloquees",        # Outcomes-Blocks : Passes bloquées par adversaire

    # Colonnes générales
    "cle_primaire",           # clé primaire
]

col_def = [
    "ligue",                # league
    "saison",               # season
    "equipe",               # team
    "joueur",               # player
    "nationalite",          # nation
    "poste",                # pos
    "age",                  # age
    "annee_naissance",      # born
    "temps_90s",            # 90s (minutes jouées divisées par 90)

    # Tacles
    "nombre_tacles",                 # Tackles-Tkl : Nombre de tacles effectués
    "tacles_gagnes",                 # Tackles-TklW : Tacles gagnés (possession récupérée)
    "tacles_dans_1_3_defensif",     # Tackles-Def 3rd : Tacles dans le tiers défensif
    "tacles_dans_1_3_central",      # Tackles-Mid 3rd : Tacles dans le tiers central
    "tacles_dans_1_3_offensif",     # Tackles-Att 3rd : Tacles dans le tiers offensif

    # Duels / Challenges
    "dribbleurs_tacles",             # Challenges-Tkl : Nombre de dribbleurs taclés
    "duels_tentés",                  # Challenges-Att : Nombre de duels/challenges tentés (échoués + réussis)
    "pourcentage_dribbleurs_tacles",# Challenges-Tkl% : % de dribbleurs taclés (réussite)
    "duels_perdus",                  # Challenges-Lost : Duels/challenges perdus

    # Dégagements / Blocks
    "nombre_blocages",               # Blocks-Blocks : Nombre de blocages (du ballon)
    "tirs_blocques",                 # Blocks-Sh : Nombre de tirs bloqués
    "passes_blocquees",              # Blocks-Pass : Nombre de passes bloquées

    # Interceptions
    "interceptions",                 # Int : Interceptions

    # Tacles + Interceptions
    "tacles_plus_interceptions",    # Tkl+Int : Total tacles + interceptions

    # Dégagements
    "degagements",                  # Clr : Dégagements

    # Erreurs
    "erreurs",                     # Err : Erreurs menant à un tir adverse

    # Colonnes générales
    "cle_primaire",                # clé primaire
]

col_possession = [
    "ligue",                # league
    "saison",               # season
    "equipe",               # team
    "joueur",               # player
    "nationalite",          # nation
    "poste",                # pos
    "age",                  # age
    "annee_naissance",      # born
    "temps_90s",            # 90s (minutes jouées divisées par 90)

    # Touches de balle
    "touches_ballon",            # Touches-Touches : Nombre de touches de balle (recevoir, dribbler, passer compte comme 1)
    "touches_dans_surface_def",  # Touches-Def Pen : Touches dans la surface défensive
    "touches_dans_tiers_def",    # Touches-Def 3rd : Touches dans le tiers défensif
    "touches_dans_tiers_central",# Touches-Mid 3rd : Touches dans le tiers central
    "touches_dans_tiers_off",    # Touches-Att 3rd : Touches dans le tiers offensif
    "touches_dans_surface_off",  # Touches-Att Pen : Touches dans la surface offensive
    "touches_ballon_jeu",        # Touches-Live : Touches en jeu (hors corners, coups francs, touches, dégagements, penalties)

    # Dribbles / Take-Ons
    "dribbles_tentes",           # Take-Ons-Att : Tentatives de dribbles face à un défenseur
    "dribbles_reussis",          # Take-Ons-Succ : Dribbles réussis
    "pourcentage_reussite_dribble", # Take-Ons-Succ% : % de dribbles réussis
    "dribbles_subis",            # Take-Ons-Tkld : Nombre de fois taclé pendant un dribble
    "pourcentage_tacles_sur_dribble", # Take-Ons-Tkld% : % de tacles subis pendant un dribble

    # Courses avec le ballon
    "courses_total",             # Carries-Carries : Nombre de courses avec le ballon
    "distance_totale_courses",   # Carries-TotDist : Distance totale parcourue avec le ballon (yards)
    "distance_progressive_courses", # Carries-PrgDist : Distance progressive avec le ballon (vers le but adverse)
    "courses_progressives",      # Carries-PrgC : Courses progressives (au moins 10 yards vers le but dans les 6 derniers passes)
    "courses_dans_1_3_off",      # Carries-1/3 : Courses dans le tiers offensif
    "courses_dans_surface_off",  # Carries-CPA : Courses dans la surface de réparation adverse
    "mauvaises_receptions",     # Carries-Mis : Nombre de mauvaises réceptions / contrôles ratés
    "ballon_perdu",              # Carries-Dis : Nombre de pertes de balle après tacle adverse (hors dribbles)

    # Réceptions de passes
    "passes_recues",             # Receiving-Rec : Passes reçues avec succès
    "passes_recues_progressives",# Receiving-PrgR : Passes reçues progressives (vers le but adverse)

    # Colonnes générales
    "cle_primaire",             # clé primaire
]


col_tps_jeu = [
    "ligue",                # league
    "saison",               # season
    "equipe",               # team
    "joueur",               # player
    "nationalite",          # nation
    "poste",                # pos
    "age",                  # age
    "annee_naissance",      # born

    # Temps de jeu
    "matchs_joues",             # Playing Time-MP : Matchs joués par le joueur ou l’équipe
    "minutes_jouees",           # Playing Time-Min : Minutes jouées au total
    "minutes_par_match",        # Playing Time-Mn/MP : Minutes jouées en moyenne par match joué
    "pourcentage_minutes",      # Playing Time-Min% : Pourcentage de minutes jouées par rapport au total de l’équipe
    "temps_90s",                # Playing Time-90s : Minutes jouées divisées par 90

    # Titularisations
    "titularisations",          # Starts-Starts : Nombre de matchs commencés en tant que titulaire
    "minutes_par_titularisation", # Starts-Mn/Start : Minutes jouées en moyenne par match commencé
    "matchs_complets",          # Starts-Compl : Nombre de matchs joués en entier

    # Remplacements
    "entrées_remplacement",     # Subs-Subs : Nombre de matchs joués en tant que remplaçant
    "minutes_par_remplacement", # Subs-Mn/Sub : Minutes jouées en moyenne par match en tant que remplaçant
    "remplaçant_non_utilisé",   # Subs-unSub : Nombre de fois remplaçant non utilisé

    # Succès de l’équipe
    "points_par_match",          # Team Success-PPM : Moyenne de points par match avec le joueur sur le terrain
    "buts_pour_sur_terrain",    # Team Success-onG : Buts marqués par l’équipe lorsque le joueur est sur le terrain
    "buts_contre_sur_terrain",  # Team Success-onGA : Buts encaissés par l’équipe lorsque le joueur est sur le terrain
    "plus_moins",               # Team Success-+/- : Différence buts marqués - buts encaissés avec le joueur sur le terrain
    "plus_moins_par_90",        # Team Success-+/-90 : Plus/Moins par 90 minutes

    "plus_moins_net_90",        # Team Success-On-Off : Différence nette plus/moins par 90 minutes sur terrain vs hors terrain

    # Succès de l’équipe (xG)
    "xg_sur_terrain",           # Team Success (xG)-onxG : Buts attendus par l’équipe avec le joueur sur le terrain
    "xga_sur_terrain",          # Team Success (xG)-onxGA : Buts attendus encaissés par l’équipe avec le joueur sur le terrain
    "xg_plus_moins",            # Team Success (xG)-xG+/- : Différence buts attendus marqués - encaissés
    "xg_plus_moins_par_90",     # Team Success (xG)-xG+/-90 : Plus/Moins de buts attendus par 90 minutes
    "xg_plus_moins_net_90",     # Team Success (xG)-On-Off : Différence nette plus/moins de buts attendus par 90 minutes sur terrain vs hors terrain

    # Colonnes générales
    "cle_primaire",             # clé primaire
]

col_autres = [
    "ligue",                # league
    "saison",               # season
    "equipe",               # team
    "joueur",               # player
    "nationalite",          # nation
    "poste",                # pos
    "age",                  # age
    "annee_naissance",      # born
    "temps_90s",            # 90s (minutes jouées divisées par 90)

    # Cartons et fautes
    "cartons_jaunes",           # Performance-CrdY : Cartons jaunes
    "cartons_rouges",           # Performance-CrdR : Cartons rouges
    "second_carton_jaune",      # Performance-2CrdY : Deuxième carton jaune
    "fautes_commises",          # Performance-Fls : Fautes commises
    "fautes_subies",            # Performance-Fld : Fautes subies
    "hors_jeu",                 # Performance-Off : Hors-jeu
    "centres",                  # Performance-Crs : Centres
    "interceptions",            # Performance-Int : Interceptions
    "tacles_gagnes",            # Performance-TklW : Tacles gagnés
    "penalties_gagnes",         # Performance-PKwon : Penalties gagnés
    "penalties_concedes",       # Performance-PKcon : Penalties concédés
    "buts_contre_son_camp",    # Performance-OG : Buts contre son camp
    "recuperations_ballon",     # Performance-Recov : Récupérations de balle

    # Duels aériens
    "duels_aeriens_gagnes",     # Aerial Duels-Won : Duels aériens gagnés
    "duels_aeriens_perdus",     # Aerial Duels-Lost : Duels aériens perdus
    "pourcentage_duels_aeriens_gagnes", # Aerial Duels-Won% : Pourcentage de duels aériens gagnés

    # Colonnes générales
    "cle_primaire",             # clé primaire
]

# %% [markdown]
# ## Joueurs

# %%
joueurs_standard.columns = col_standard
joueurs_playing_time.columns = col_tps_jeu
joueurs_keeper.columns = col_gardien
joueurs_keeper_adv.columns = col_gardiens_1
joueurs_shooting.columns = col_tirs
joueurs_goal_shot_creation.columns = col_actions_creation
joueurs_passing.columns = col_passes
joueurs_passing_types.columns = col_pass_types
joueurs_possession.columns = col_possession
joueurs_defense.columns = col_def
joueurs_misc.columns = col_autres

# Liste de tuples (DataFrame, prefixe)
dfs_prefixes = [
    (joueurs_standard, "standard"),
    (joueurs_playing_time, "temps_jeu"),
    (joueurs_keeper, "gardien"),
    (joueurs_keeper_adv, "gardien_avance"),
    (joueurs_shooting, "tirs"),
    (joueurs_goal_shot_creation, "actions_creation"),
    (joueurs_passing, "passes"),
    (joueurs_passing_types, "types_passes"),
    (joueurs_possession, "possession"),
    (joueurs_defense, "defense"),
    (joueurs_misc, "autre")
]

key_cols = ["ligue", "saison", "equipe", "joueur", "nationalite", "poste", "age", "annee_naissance"]

for df, prefix in dfs_prefixes:
    new_columns = []
    for col in df.columns:
        if col in key_cols:
            new_columns.append(col)  # on garde le nom d'origine pour les clés
        else:
            new_columns.append(f"{prefix}_{col}")  # on ajoute le préfixe pour les autres colonnes
    df.columns = new_columns


print("Colonnes joueurs_standard :", joueurs_standard.columns.tolist())
print("*"*100)
print("Colonnes joueurs_playing_time :", joueurs_playing_time.columns.tolist())
print("*"*100)
print("Colonnes joueurs_keeper :", joueurs_keeper.columns.tolist())
print("*"*100)
print("*"*100)
print("Colonnes joueurs_keeper_adv :", joueurs_keeper_adv.columns.tolist())
print("*"*100)
print("Colonnes joueurs_shooting :", joueurs_shooting.columns.tolist())
print("*"*100)
print("Colonnes joueurs_goal_shot_creation :", joueurs_goal_shot_creation.columns.tolist())
print("*"*100)
print("Colonnes joueurs_passing :", joueurs_passing.columns.tolist())
print("*"*100)
print("Colonnes joueurs_passing_types :", joueurs_passing_types.columns.tolist())
print("*"*100)
print("Colonnes joueurs_possession :", joueurs_possession.columns.tolist())
print("*"*100)
print("Colonnes joueurs_defense :", joueurs_defense.columns.tolist())
print("*"*100)
print("Colonnes joueurs_misc :", joueurs_misc.columns.tolist())
# Out:
# Colonnes joueurs_standard : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'standard_matchs_joues', 'standard_titularisations', 'standard_minutes_jouees', 'standard_matchs_90_minutes', 'standard_buts', 'standard_passes_decisives', 'standard_buts_plus_passes', 'standard_buts_hors_penalty', 'standard_penaltys_marques', 'standard_penaltys_tentes', 'standard_cartons_jaunes', 'standard_cartons_rouges', 'standard_buts_attendus', 'standard_buts_attendus_hors_penalty', 'standard_passes_attendues', 'standard_buts_hors_penalty_plus_passes_attendues', 'standard_conduites_progressives', 'standard_passes_progressives', 'standard_passes_progressives_recues', 'standard_buts_par_90', 'standard_passes_decisives_par_90', 'standard_buts_plus_passes_par_90', 'standard_buts_hors_penalty_par_90', 'standard_buts_plus_passes_hors_penalty_par_90', 'standard_buts_attendus_par_90', 'standard_passes_attendues_par_90', 'standard_buts_plus_passes_attendues_par_90', 'standard_buts_attendus_hors_penalty_par_90', 'standard_buts_hors_penalty_plus_passes_attendues_90', 'standard_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_playing_time : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'temps_jeu_matchs_joues', 'temps_jeu_minutes_jouees', 'temps_jeu_minutes_par_match', 'temps_jeu_pourcentage_minutes', 'temps_jeu_temps_90s', 'temps_jeu_titularisations', 'temps_jeu_minutes_par_titularisation', 'temps_jeu_matchs_complets', 'temps_jeu_entrées_remplacement', 'temps_jeu_minutes_par_remplacement', 'temps_jeu_remplaçant_non_utilisé', 'temps_jeu_points_par_match', 'temps_jeu_buts_pour_sur_terrain', 'temps_jeu_buts_contre_sur_terrain', 'temps_jeu_plus_moins', 'temps_jeu_plus_moins_par_90', 'temps_jeu_plus_moins_net_90', 'temps_jeu_xg_sur_terrain', 'temps_jeu_xga_sur_terrain', 'temps_jeu_xg_plus_moins', 'temps_jeu_xg_plus_moins_par_90', 'temps_jeu_xg_plus_moins_net_90', 'temps_jeu_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_keeper : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'gardien_matchs_joues', 'gardien_titularisations', 'gardien_minutes_jouees', 'gardien_matchs_90_minutes', 'gardien_buts_encaisses', 'gardien_buts_encaisses_par_90', 'gardien_tirs_cadres_subis', 'gardien_arrets', 'gardien_pourcentage_arrets', 'gardien_victoires', 'gardien_nuls', 'gardien_defaites', 'gardien_clean_sheets', 'gardien_pourcentage_clean_sheets', 'gardien_penaltys_tentes', 'gardien_penaltys_concedes', 'gardien_penaltys_arretes', 'gardien_penaltys_rates', 'gardien_pourcentage_arrets_penalty', 'gardien_cle_primaire']
# ****************************************************************************************************
# ****************************************************************************************************
# Colonnes joueurs_keeper_adv : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'gardien_avance_temps_90s', 'gardien_avance_buts_encaisses', 'gardien_avance_penaltys_encaisses', 'gardien_avance_coup_francs_encaisses', 'gardien_avance_corners_encaisses', 'gardien_avance_csc_encaisses', 'gardien_avance_buts_att_ps', 'gardien_avance_buts_att_ps_par_tir_cadre', 'gardien_avance_diff_buts_att_ps_encaisses', 'gardien_avance_diff_buts_att_ps_encaisses_90', 'gardien_avance_passes_longues_reussies', 'gardien_avance_passes_longues_tentees', 'gardien_avance_passes_longues_pct', 'gardien_avance_passes_tentees_gk', 'gardien_avance_remises_a_la_main', 'gardien_avance_passes_lance_pct', 'gardien_avance_longueur_moyenne_passe', 'gardien_avance_degagements_tentes', 'gardien_avance_degagements_pct_longs', 'gardien_avance_longueur_moyenne_degagement', 'gardien_avance_centres_subis', 'gardien_avance_centres_interceptes', 'gardien_avance_centres_interceptes_pct', 'gardien_avance_actions_def_hors_surface', 'gardien_avance_actions_def_hors_surface_par90', 'gardien_avance_distance_moy_actions_def', 'gardien_avance_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_shooting : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'tirs_temps_90s', 'tirs_buts', 'tirs_tirs_totaux', 'tirs_tirs_cadres', 'tirs_pct_tirs_cadres', 'tirs_tirs_par_90', 'tirs_tirs_cadres_par_90', 'tirs_buts_par_tir', 'tirs_buts_par_tir_cadre', 'tirs_distance_moy_tir', 'tirs_tirs_coup_franc', 'tirs_penaltys_marques', 'tirs_penaltys_tentes', 'tirs_buts_attendus_xg', 'tirs_buts_attendus_np_xg', 'tirs_buts_attendus_np_xg_par_tir', 'tirs_diff_buts_buts_attendus', 'tirs_diff_buts_np_buts_attendus', 'tirs_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_goal_shot_creation : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'actions_creation_temps_90s', 'actions_creation_action_tir_total', 'actions_creation_action_tir_par_90', 'actions_creation_action_tir_passes_vives', 'actions_creation_action_tir_passes_mortes', 'actions_creation_action_tir_dribbles', 'actions_creation_action_tir_tirs', 'actions_creation_action_tir_fautes_subies', 'actions_creation_action_tir_actions_def', 'actions_creation_action_but_total', 'actions_creation_action_but_par_90', 'actions_creation_action_but_passes_vives', 'actions_creation_action_but_passes_mortes', 'actions_creation_action_but_dribbles', 'actions_creation_action_but_tirs', 'actions_creation_action_but_fautes_subies', 'actions_creation_action_but_actions_def', 'actions_creation_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_passing : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'passes_temps_90s', 'passes_passes_reussies', 'passes_passes_tentees', 'passes_pct_reussite_passes', 'passes_distance_totale_passes', 'passes_distance_progressive', 'passes_passes_courtes_reussies', 'passes_passes_courtes_tentees', 'passes_pct_reussite_courtes', 'passes_passes_moyennes_reussies', 'passes_passes_moyennes_tentees', 'passes_pct_reussite_moyennes', 'passes_passes_longues_reussies', 'passes_passes_longues_tentees', 'passes_pct_reussite_longues', 'passes_passes_decisives', 'passes_buts_attendus_passe_decisive', 'passes_passes_attendues', 'passes_diff_passes_decisives_attendues', 'passes_passes_cles', 'passes_passes_dans_tiers_final', 'passes_passes_dans_surface_penalite', 'passes_centres_dans_surface_penalite', 'passes_passes_progressives', 'passes_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_passing_types : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'types_passes_temps_90s', 'types_passes_passes_tentees', 'types_passes_passes_vives', 'types_passes_passes_mortes', 'types_passes_passes_coups_francs', 'types_passes_passes_passees_en_rupture', 'types_passes_passes_deviation_large', 'types_passes_centres', 'types_passes_touches_reprises', 'types_passes_corners_tentes', 'types_passes_corners_entrant', 'types_passes_corners_sortant', 'types_passes_corners_droits', 'types_passes_passes_reussies', 'types_passes_passes_hors_jeu', 'types_passes_passes_bloquees', 'types_passes_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_possession : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'possession_temps_90s', 'possession_touches_ballon', 'possession_touches_dans_surface_def', 'possession_touches_dans_tiers_def', 'possession_touches_dans_tiers_central', 'possession_touches_dans_tiers_off', 'possession_touches_dans_surface_off', 'possession_touches_ballon_jeu', 'possession_dribbles_tentes', 'possession_dribbles_reussis', 'possession_pourcentage_reussite_dribble', 'possession_dribbles_subis', 'possession_pourcentage_tacles_sur_dribble', 'possession_courses_total', 'possession_distance_totale_courses', 'possession_distance_progressive_courses', 'possession_courses_progressives', 'possession_courses_dans_1_3_off', 'possession_courses_dans_surface_off', 'possession_mauvaises_receptions', 'possession_ballon_perdu', 'possession_passes_recues', 'possession_passes_recues_progressives', 'possession_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_defense : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'defense_temps_90s', 'defense_nombre_tacles', 'defense_tacles_gagnes', 'defense_tacles_dans_1_3_defensif', 'defense_tacles_dans_1_3_central', 'defense_tacles_dans_1_3_offensif', 'defense_dribbleurs_tacles', 'defense_duels_tentés', 'defense_pourcentage_dribbleurs_tacles', 'defense_duels_perdus', 'defense_nombre_blocages', 'defense_tirs_blocques', 'defense_passes_blocquees', 'defense_interceptions', 'defense_tacles_plus_interceptions', 'defense_degagements', 'defense_erreurs', 'defense_cle_primaire']
# ****************************************************************************************************
# Colonnes joueurs_misc : ['ligue', 'saison', 'equipe', 'joueur', 'nationalite', 'poste', 'age', 'annee_naissance', 'autre_temps_90s', 'autre_cartons_jaunes', 'autre_cartons_rouges', 'autre_second_carton_jaune', 'autre_fautes_commises', 'autre_fautes_subies', 'autre_hors_jeu', 'autre_centres', 'autre_interceptions', 'autre_tacles_gagnes', 'autre_penalties_gagnes', 'autre_penalties_concedes', 'autre_buts_contre_son_camp', 'autre_recuperations_ballon', 'autre_duels_aeriens_gagnes', 'autre_duels_aeriens_perdus', 'autre_pourcentage_duels_aeriens_gagnes', 'autre_cle_primaire']

# %% [markdown]
# # Featuring engeniering

# %%
# Extraction des DataFrames renommés dans une liste
dfs_renamed = [df for df, _ in dfs_prefixes]

# Fusion successive sur les colonnes clés
df_joueurs = dfs_renamed[0]
for df in dfs_renamed[1:]:
    df_joueurs = pd.merge(df_joueurs, df, on=key_cols, how='outer')

# Afficher les premières colonnes du résultat pour vérification
df_joueurs.columns
df_joueurs["date_chargement"] = datetime.now().strftime("%Y-%m-%d")

# %%
#Exemple de selection
df = df_joueurs[key_cols + df_joueurs.filter(regex=r'^types_passes').columns.tolist()]
print(df["ligue"].unique())
print(df["equipe"].unique())
df[df["equipe"].str.contains("Marseille")]
# Out:
# ['ENG-Premier League' 'ESP-La Liga' 'FRA-Ligue 1' 'GER-Bundesliga'
#  'ITA-Serie A']
# <StringArray>
# [        'Arsenal',     'Aston Villa',     'Bournemouth',       'Brentford',
#         'Brighton',         'Chelsea',  'Crystal Palace',         'Everton',
#           'Fulham',    'Ipswich Town',  'Leicester City',       'Liverpool',
#  'Manchester City',  'Manchester Utd',   'Newcastle Utd', "Nott'ham Forest",
#      'Southampton',       'Tottenham',        'West Ham',          'Wolves',
#           'Alavés',   'Athletic Club', 'Atlético Madrid',       'Barcelona',
#            'Betis',      'Celta Vigo',        'Espanyol',          'Getafe',
#           'Girona',      'Las Palmas',         'Leganés',        'Mallorca',
#          'Osasuna',  'Rayo Vallecano',     'Real Madrid',   'Real Sociedad',
#          'Sevilla',        'Valencia',      'Valladolid',      'Villarreal',
#           'Angers',         'Auxerre',           'Brest',        'Le Havre',
#             'Lens',           'Lille',            'Lyon',       'Marseille',
#           'Monaco',     'Montpellier',          'Nantes',            'Nice',
#        'Paris S-G',           'Reims',          'Rennes',   'Saint-Étienne',
#       'Strasbourg',        'Toulouse',        'Augsburg',   'Bayern Munich',
#           'Bochum',        'Dortmund',  'Eint Frankfurt',        'Freiburg',
#         'Gladbach',      'Heidenheim',      'Hoffenheim',   'Holstein Kiel',
#       'Leverkusen',        'Mainz 05',      'RB Leipzig',       'St. Pauli',
#        'Stuttgart',    'Union Berlin',   'Werder Bremen',       'Wolfsburg',
#         'Atalanta',         'Bologna',        'Cagliari',            'Como',
#           'Empoli',      'Fiorentina',           'Genoa',   'Hellas Verona',
#            'Inter',        'Juventus',           'Lazio',           'Lecce',
#            'Milan',           'Monza',          'Napoli',           'Parma',
#             'Roma',          'Torino',         'Udinese',         'Venezia']
# Length: 96, dtype: string
#             ligue saison     equipe                joueur nationalite  poste  \
# 1643  FRA-Ligue 1   2425  Marseille         Adrien Rabiot         FRA     MF
# 1644  FRA-Ligue 1   2425  Marseille            Amar Dedić         BIH     DF
# 1645  FRA-Ligue 1   2425  Marseille          Amine Gouiri         ALG  FW,MF
# 1646  FRA-Ligue 1   2425  Marseille           Amine Harit         MAR     MF
# 1647  FRA-Ligue 1   2425  Marseille            Bamo Meïté         CIV     DF
# 1648  FRA-Ligue 1   2425  Marseille           Bilal Nadir         MAR     MF
# 1649  FRA-Ligue 1   2425  Marseille         Darryl Bakola         FRA  DF,MF
# 1650  FRA-Ligue 1   2425  Marseille       Derek Cornelius         CAN     DF
# 1651  FRA-Ligue 1   2425  Marseille             Elye Wahi         FRA     FW
# 1652  FRA-Ligue 1   2425  Marseille  Emmanuel Koum Mbondo         FRA     DF
# 1653  FRA-Ligue 1   2425  Marseille          Enzo Sternal         FRA  FW,MF
# 1654  FRA-Ligue 1   2425  Marseille  Faris Pemi Moumbagna         CMR     FW
# 1655  FRA-Ligue 1   2425  Marseille           Gael Lafont         FRA     FW
# 1656  FRA-Ligue 1   2425  Marseille    Geoffrey Kondogbia         CTA  DF,MF
# 1657  FRA-Ligue 1   2425  Marseille        Gerónimo Rulli         ARG     GK
# 1658  FRA-Ligue 1   2425  Marseille       Ismaël Bennacer         ALG     MF
# 1659  FRA-Ligue 1   2425  Marseille           Ismaël Koné         CAN  MF,FW
# 1660  FRA-Ligue 1   2425  Marseille      Jeffrey De Lange         NED     GK
# 1661  FRA-Ligue 1   2425  Marseille        Jelle Van Neck         BEL     GK
# 1662  FRA-Ligue 1   2425  Marseille              Jon Rowe         ENG  FW,MF
# 1663  FRA-Ligue 1   2425  Marseille     Keyliane Abdallah         FRA     FW
# 1664  FRA-Ligue 1   2425  Marseille      Leonardo Balerdi         ARG     DF
# 1665  FRA-Ligue 1   2425  Marseille       Lilian Brassier         FRA     DF
# 1666  FRA-Ligue 1   2425  Marseille         Luis Henrique         BRA  DF,FW
# 1667  FRA-Ligue 1   2425  Marseille           Luiz Felipe         ITA     DF
# 1668  FRA-Ligue 1   2425  Marseille       Mason Greenwood         ENG  FW,MF
# 1669  FRA-Ligue 1   2425  Marseille  Michael Amir Murillo         PAN     DF
# 1670  FRA-Ligue 1   2425  Marseille           Neal Maupay         FRA     FW
# 1671  FRA-Ligue 1   2425  Marseille       Pierre Højbjerg         DEN     MF
# 1672  FRA-Ligue 1   2425  Marseille            Pol Lirola         ESP     DF
# 1673  FRA-Ligue 1   2425  Marseille        Quentin Merlin         FRA     DF
# 1674  FRA-Ligue 1   2425  Marseille           Robinio Vaz         FRA     FW
# 1675  FRA-Ligue 1   2425  Marseille     Roggerio Nyakossi         SUI     DF
# 1676  FRA-Ligue 1   2425  Marseille      Rony Mimb Baheng         CMR     DF
# 1677  FRA-Ligue 1   2425  Marseille      Salim Ben Seghir         FRA     FW
# 1678  FRA-Ligue 1   2425  Marseille        Ulisses Garcia         SUI     DF
# 1679  FRA-Ligue 1   2425  Marseille      Valentin Carboni         ARG  MF,FW
# 1680  FRA-Ligue 1   2425  Marseille      Valentin Rongier         FRA  MF,DF
#
#          age  annee_naissance  types_passes_temps_90s  \
# 1643  29-355             1995                    19.6
# 1644  22-218             2002                     2.3
# 1645  25-036             2000                     6.1
# 1646  27-279             1997                     5.2
# 1647  23-111             2001                     0.3
# 1648  21-116             2003                     3.9
# 1649  17-114             2007                     0.2
# 1650  27-119             1997                    13.0
# 1651  22-081             2003                     6.4
# 1652  19-047             2006                     0.1
# 1653  17-300             2007                     0.3
# 1654  24-266             2000                     0.1
# 1655  18-290             2006                    <NA>
# 1656  32-037             1993                    16.6
# 1657  32-308             1992                    26.0
# 1658  27-113             1997                     3.6
# 1659  22-291             2002                     4.0
# 1660  26-357             1998                    <NA>
# 1661  21-017             2004                    <NA>
# 1662  21-328             2003                     5.8
# 1663  18-353             2006                     0.0
# 1664  26-057             1999                    21.0
# 1665  25-142             1999                     8.7
# 1666  23-100             2001                    22.8
# 1667  28-002             1997                     0.8
# 1668  23-174             2001                    23.3
# 1669  29-041             1996                    20.1
# 1670  28-222             1996                    10.2
# 1671  29-231             1995                    23.9
# 1672  27-223             1997                     5.9
# 1673  22-312             2002                    13.7
# 1674  18-035             2007                     0.8
# 1675  21-070             2004                    <NA>
# 1676  19-336             2005                    <NA>
# 1677  22-028             2003                    <NA>
# 1678  29-072             1996                     5.6
# 1679  20-019             2005                     1.1
# 1680  30-107             1994                    11.4
#
#       types_passes_passes_tentees  ...  types_passes_centres  \
# 1643                         1138  ...                    26
# 1644                          140  ...                     2
# 1645                          213  ...                    30
# 1646                          225  ...                     6
# 1647                           28  ...                     0
# 1648                          229  ...                     6
# 1649                           13  ...                     0
# 1650                         1124  ...                     4
# 1651                          111  ...                     2
# 1652                            9  ...                     0
# 1653                            8  ...                     0
# 1654                            0  ...                     0
# 1655                         <NA>  ...                  <NA>
# 1656                         1337  ...                     3
# 1657                          936  ...                     0
# 1658                          476  ...                    17
# 1659                          180  ...                     3
# 1660                         <NA>  ...                  <NA>
# 1661                         <NA>  ...                  <NA>
# 1662                          197  ...                    20
# 1663                            2  ...                     0
# 1664                         2193  ...                     1
# 1665                          653  ...                     5
# 1666                         1103  ...                    76
# 1667                           32  ...                     0
# 1668                         1079  ...                    83
# 1669                         1433  ...                    24
# 1670                          266  ...                     1
# 1671                         2395  ...                    18
# 1672                          300  ...                    13
# 1673                          913  ...                    74
# 1674                            8  ...                     1
# 1675                         <NA>  ...                  <NA>
# 1676                         <NA>  ...                  <NA>
# 1677                         <NA>  ...                  <NA>
# 1678                          327  ...                    19
# 1679                           64  ...                     2
# 1680                          951  ...                     3
#
#       types_passes_touches_reprises  types_passes_corners_tentes  \
# 1643                              7                            0
# 1644                             19                            0
# 1645                              0                           24
# 1646                              0                            5
# 1647                              4                            0
# 1648                              0                            3
# 1649                              0                            0
# 1650                              3                            0
# 1651                              0                            0
# 1652                              2                            0
# 1653                              0                            0
# 1654                              0                            0
# 1655                           <NA>                         <NA>
# 1656                              6                            0
# 1657                              0                            0
# 1658                              1                           15
# 1659                              0                            0
# 1660                           <NA>                         <NA>
# 1661                           <NA>                         <NA>
# 1662                              2                            4
# 1663                              0                            0
# 1664                              1                            0
# 1665                             21                            0
# 1666                             41                            8
# 1667                              2                            0
# 1668                              7                           34
# 1669                            113                            0
# 1670                              3                            0
# 1671                              7                           13
# 1672                             35                            0
# 1673                             89                           20
# 1674                              0                            0
# 1675                           <NA>                         <NA>
# 1676                           <NA>                         <NA>
# 1677                           <NA>                         <NA>
# 1678                             51                            0
# 1679                              2                            0
# 1680                             11                            0
#
#       types_passes_corners_entrant  types_passes_corners_sortant  \
# 1643                             0                             0
# 1644                             0                             0
# 1645                             8                            14
# 1646                             2                             1
# 1647                             0                             0
# 1648                             1                             0
# 1649                             0                             0
# 1650                             0                             0
# 1651                             0                             0
# 1652                             0                             0
# 1653                             0                             0
# 1654                             0                             0
# 1655                          <NA>                          <NA>
# 1656                             0                             0
# 1657                             0                             0
# 1658                            12                             3
# 1659                             0                             0
# 1660                          <NA>                          <NA>
# 1661                          <NA>                          <NA>
# 1662                             3                             1
# 1663                             0                             0
# 1664                             0                             0
# 1665                             0                             0
# 1666                             1                             5
# 1667                             0                             0
# 1668                            25                             1
# 1669                             0                             0
# 1670                             0                             0
# 1671                             6                             5
# 1672                             0                             0
# 1673                             6                             9
# 1674                             0                             0
# 1675                          <NA>                          <NA>
# 1676                          <NA>                          <NA>
# 1677                          <NA>                          <NA>
# 1678                             0                             0
# 1679                             0                             0
# 1680                             0                             0
#
#       types_passes_corners_droits  types_passes_passes_reussies  \
# 1643                            0                           977
# 1644                            0                           118
# 1645                            0                           176
# 1646                            0                           188
# 1647                            0                            26
# 1648                            0                           199
# 1649                            0                            12
# 1650                            0                          1048
# 1651                            0                            88
# 1652                            0                             8
# 1653                            0                             7
# 1654                            0                             0
# 1655                         <NA>                          <NA>
# 1656                            0                          1233
# 1657                            0                           808
# 1658                            0                           436
# 1659                            0                           156
# 1660                         <NA>                          <NA>
# 1661                         <NA>                          <NA>
# 1662                            0                           161
# 1663                            0                             2
# 1664                            0                          2063
# 1665                            0                           560
# 1666                            0                           893
# 1667                            0                            28
# 1668                            0                           849
# 1669                            0                          1269
# 1670                            0                           221
# 1671                            0                          2209
# 1672                            0                           242
# 1673                            0                           756
# 1674                            0                             2
# 1675                         <NA>                          <NA>
# 1676                         <NA>                          <NA>
# 1677                         <NA>                          <NA>
# 1678                            0                           270
# 1679                            0                            57
# 1680                            0                           864
#
#       types_passes_passes_hors_jeu  types_passes_passes_bloquees  \
# 1643                             3                            26
# 1644                             0                             5
# 1645                             1                             3
# 1646                             4                             6
# 1647                             0                             1
# 1648                             1                             9
# 1649                             0                             0
# 1650                             2                             8
# 1651                             1                             6
# 1652                             0                             0
# 1653                             0                             0
# 1654                             0                             0
# 1655                          <NA>                          <NA>
# 1656                             1                             8
# 1657                             1                             0
# 1658                             0                             5
# 1659                             0                             3
# 1660                          <NA>                          <NA>
# 1661                          <NA>                          <NA>
# 1662                             0                             6
# 1663                             0                             0
# 1664                             3                            12
# 1665                             5                             6
# 1666                             2                            26
# 1667                             0                             1
# 1668                             5                            16
# 1669                             2                            21
# 1670                             0                             8
# 1671                             2                            18
# 1672                             1                            11
# 1673                             2                            20
# 1674                             0                             0
# 1675                          <NA>                          <NA>
# 1676                          <NA>                          <NA>
# 1677                          <NA>                          <NA>
# 1678                             2                             6
# 1679                             0                             3
# 1680                             1                            16
#
#              types_passes_cle_primaire
# 1643         Adrien Rabiot - Marseille
# 1644            Amar Dedić - Marseille
# 1645          Amine Gouiri - Marseille
# 1646           Amine Harit - Marseille
# 1647            Bamo Meïté - Marseille
# 1648           Bilal Nadir - Marseille
# 1649         Darryl Bakola - Marseille
# 1650       Derek Cornelius - Marseille
# 1651             Elye Wahi - Marseille
# 1652  Emmanuel Koum Mbondo - Marseille
# 1653          Enzo Sternal - Marseille
# 1654  Faris Pemi Moumbagna - Marseille
# 1655                               NaN
# 1656    Geoffrey Kondogbia - Marseille
# 1657        Gerónimo Rulli - Marseille
# 1658       Ismaël Bennacer - Marseille
# 1659           Ismaël Koné - Marseille
# 1660                               NaN
# 1661                               NaN
# 1662              Jon Rowe - Marseille
# 1663     Keyliane Abdallah - Marseille
# 1664      Leonardo Balerdi - Marseille
# 1665       Lilian Brassier - Marseille
# 1666         Luis Henrique - Marseille
# 1667           Luiz Felipe - Marseille
# 1668       Mason Greenwood - Marseille
# 1669  Michael Amir Murillo - Marseille
# 1670           Neal Maupay - Marseille
# 1671       Pierre Højbjerg - Marseille
# 1672            Pol Lirola - Marseille
# 1673        Quentin Merlin - Marseille
# 1674           Robinio Vaz - Marseille
# 1675                               NaN
# 1676                               NaN
# 1677                               NaN
# 1678        Ulisses Garcia - Marseille
# 1679      Valentin Carboni - Marseille
# 1680      Valentin Rongier - Marseille
#
# [38 rows x 25 columns]

# %%
import nbformat
from nbconvert import PythonExporter

notebook_filename = "bdd_foot.ipynb"
script_filename = "bdd_foot.py"

with open(notebook_filename) as f:
    nb = nbformat.read(f, as_version=4)

exporter = PythonExporter()
source, _ = exporter.from_notebook_node(nb)

with open(script_filename, "w") as f:
    f.write(source)
